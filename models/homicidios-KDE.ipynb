# %% [markdown]
# # Data Lesiones Homicidios

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime
import os
from unidecode import unidecode

# %%
files_1 = ['./data/homicidios/' + str(i) + '.xlsx' for i in range(2010, 2013)]
files_2 = ['./data/homicidios/' + str(i) + '.xls' for i in range(2013, 2020)]
files = files_1+files_2
print(files)
# Out:
# ['./data/homicidios/2010.xlsx', './data/homicidios/2011.xlsx', './data/homicidios/2012.xlsx', './data/homicidios/2013.xls', './data/homicidios/2014.xls', './data/homicidios/2015.xls', './data/homicidios/2016.xls', './data/homicidios/2017.xls', './data/homicidios/2018.xls', './data/homicidios/2019.xls']

# %%
all_dfs = []

for file in files:
    temp = pd.read_excel(file)
    
    # Eliminar acentos en el nombre de las columnas
    temp.columns = [unidecode(str(col)) for col in temp.columns]

    # Reemplazar espacios por _
    temp.columns = temp.columns.str.replace(' ', '_')
    
    # Strip
    temp.columns = temp.columns.str.strip()

    # Reemplazar espacios por _
    temp.columns = temp.columns.str.lower()

    # Reemplazar NaN, None
    temp.replace('-', np.nan, inplace=True)

    # Set axis name
    temp.rename_axis('id', inplace=True)
    
    all_dfs.append(temp)

# %%
renaming={
    'clase_sitio':'clase_de_sitio',
    'pais_nace':'pais_de_nacimiento',
    'clase_empleado':'clase_de_empleado'
}

for i in range(len(all_dfs)):
    all_dfs[i].rename(columns=renaming, inplace=True)
    
df_f = pd.concat(all_dfs, axis=0)

# %%
df_f # also try: .describe
# Out:
#                                                    fecha departamento  \
# id
# 0                                    2010-01-01 00:00:00    ANTIOQUIA
# 1                                    2010-01-01 00:00:00    ANTIOQUIA
# 2                                    2010-01-01 00:00:00    ANTIOQUIA
# 3                                    2010-01-01 00:00:00    ANTIOQUIA
# 4                                    2010-01-01 00:00:00    ANTIOQUIA
# ...                                                  ...          ...
# 12512                                2019-12-31 00:00:00        VALLE
# 12513                                                NaN          NaN
# 12514  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
# 12515                Elaboró: PT. Andrés Felipe Taborda           NaN
# 12516               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#            municipio      dia      hora                     barrio    zona  \
# id
# 0              AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
# 1         COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
# 2      MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
# 3      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...              ...      ...       ...                        ...     ...
# 12512          TULUÁ   Martes  23:50:00              Villa Liliana  URBANA
# 12513            NaN      NaN       NaN                        NaN     NaN
# 12514            NaN      NaN       NaN                        NaN     NaN
# 12515            NaN      NaN       NaN                        NaN     NaN
# 12516            NaN      NaN       NaN                        NaN     NaN
#
#                            clase_de_sitio  arma_empleada movil_agresor  ...  \
# id                                                                      ...
# 0                      FINCAS Y SIMILARES    ARMA BLANCA         A PIE  ...
# 1      FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO         A PIE  ...
# 2                           VIAS PUBLICAS  ARMA DE FUEGO         A PIE  ...
# 3                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE  ...
# 4                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE  ...
# ...                                   ...            ...           ...  ...
# 12512                       VIAS PUBLICAS  ARMA DE FUEGO     BICICLETA  ...
# 12513                                 NaN            NaN           NaN  ...
# 12514                                 NaN            NaN           NaN  ...
# 12515                                 NaN            NaN           NaN  ...
# 12516                                 NaN            NaN           NaN  ...
#
#       pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# id
# 0               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 1               COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 2               COLOMBIA          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 3               COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 4               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# ...                  ...                  ...           ...         ...
# 12512           COLOMBIA  EMPLEADO PARTICULAR           NaN  SECUNDARIA
# 12513                NaN                  NaN           NaN         NaN
# 12514                NaN                  NaN           NaN         NaN
# 12515                NaN                  NaN           NaN         NaN
# 12516                NaN                  NaN           NaN         NaN
#
#       codigo_dane 2010 2011 2012  profesion  cantidad
# id
# 0       5030000.0  1.0  NaN  NaN        NaN       NaN
# 1       5212000.0  1.0  NaN  NaN        NaN       NaN
# 2       5001000.0  1.0  NaN  NaN        NaN       NaN
# 3       5001000.0  1.0  NaN  NaN        NaN       NaN
# 4       5001000.0  1.0  NaN  NaN        NaN       NaN
# ...           ...  ...  ...  ...        ...       ...
# 12512  76834000.0  NaN  NaN  NaN        NaN       1.0
# 12513         NaN  NaN  NaN  NaN        NaN   12558.0
# 12514         NaN  NaN  NaN  NaN        NaN       NaN
# 12515         NaN  NaN  NaN  NaN        NaN       NaN
# 12516         NaN  NaN  NaN  NaN        NaN       NaN
#
# [136343 rows x 24 columns]

# %%
df_f.isnull().sum()
# Out:
# fecha                      5
# departamento              40
# municipio                 40
# dia                       40
# hora                      40
# barrio                  5119
# zona                      40
# clase_de_sitio            40
# arma_empleada             51
# movil_agresor            712
# movil_victima            522
# edad                      84
# sexo                      40
# estado_civil             688
# pais_de_nacimiento      1678
# clase_de_empleado         40
# profesiones            89689
# escolaridad              868
# codigo_dane               40
# 2010                  121392
# 2011                  120606
# 2012                  120374
# profesion             131991
# cantidad               46687
# dtype: int64

# %%
df_f.drop(columns=['2010','2011','2012','profesion'], inplace=True)

# %%
df_f
# Out:
#                                                    fecha departamento  \
# id
# 0                                    2010-01-01 00:00:00    ANTIOQUIA
# 1                                    2010-01-01 00:00:00    ANTIOQUIA
# 2                                    2010-01-01 00:00:00    ANTIOQUIA
# 3                                    2010-01-01 00:00:00    ANTIOQUIA
# 4                                    2010-01-01 00:00:00    ANTIOQUIA
# ...                                                  ...          ...
# 12512                                2019-12-31 00:00:00        VALLE
# 12513                                                NaN          NaN
# 12514  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
# 12515                Elaboró: PT. Andrés Felipe Taborda           NaN
# 12516               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#            municipio      dia      hora                     barrio    zona  \
# id
# 0              AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
# 1         COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
# 2      MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
# 3      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...              ...      ...       ...                        ...     ...
# 12512          TULUÁ   Martes  23:50:00              Villa Liliana  URBANA
# 12513            NaN      NaN       NaN                        NaN     NaN
# 12514            NaN      NaN       NaN                        NaN     NaN
# 12515            NaN      NaN       NaN                        NaN     NaN
# 12516            NaN      NaN       NaN                        NaN     NaN
#
#                            clase_de_sitio  arma_empleada movil_agresor  \
# id
# 0                      FINCAS Y SIMILARES    ARMA BLANCA         A PIE
# 1      FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO         A PIE
# 2                           VIAS PUBLICAS  ARMA DE FUEGO         A PIE
# 3                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
# 4                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
# ...                                   ...            ...           ...
# 12512                       VIAS PUBLICAS  ARMA DE FUEGO     BICICLETA
# 12513                                 NaN            NaN           NaN
# 12514                                 NaN            NaN           NaN
# 12515                                 NaN            NaN           NaN
# 12516                                 NaN            NaN           NaN
#
#       movil_victima edad       sexo estado_civil pais_de_nacimiento  \
# id
# 0             A PIE   49  MASCULINO       CASADO           COLOMBIA
# 1             A PIE   32  MASCULINO  UNION LIBRE           COLOMBIA
# 2             A PIE   33  MASCULINO  UNION LIBRE           COLOMBIA
# 3             A PIE   23  MASCULINO      SOLTERO           COLOMBIA
# 4             A PIE   23  MASCULINO      SOLTERO           COLOMBIA
# ...             ...  ...        ...          ...                ...
# 12512         A PIE   19  MASCULINO  UNION LIBRE           COLOMBIA
# 12513           NaN  NaN        NaN          NaN                NaN
# 12514           NaN  NaN        NaN          NaN                NaN
# 12515           NaN  NaN        NaN          NaN                NaN
# 12516           NaN  NaN        NaN          NaN                NaN
#
#          clase_de_empleado   profesiones escolaridad  codigo_dane  cantidad
# id
# 0      EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA    5030000.0       NaN
# 1            INDEPENDIENTE  NO REPORTADO  SECUNDARIA    5212000.0       NaN
# 2              DESEMPLEADO  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# 3               ESTUDIANTE  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# 4      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# ...                    ...           ...         ...          ...       ...
# 12512  EMPLEADO PARTICULAR           NaN  SECUNDARIA   76834000.0       1.0
# 12513                  NaN           NaN         NaN          NaN   12558.0
# 12514                  NaN           NaN         NaN          NaN       NaN
# 12515                  NaN           NaN         NaN          NaN       NaN
# 12516                  NaN           NaN         NaN          NaN       NaN
#
# [136343 rows x 20 columns]

# %%
df_f = df_f.reset_index()

# %%
df_f
# Out:
#            id                                              fecha departamento  \
# 0           0                                2010-01-01 00:00:00    ANTIOQUIA
# 1           1                                2010-01-01 00:00:00    ANTIOQUIA
# 2           2                                2010-01-01 00:00:00    ANTIOQUIA
# 3           3                                2010-01-01 00:00:00    ANTIOQUIA
# 4           4                                2010-01-01 00:00:00    ANTIOQUIA
# ...       ...                                                ...          ...
# 136338  12512                                2019-12-31 00:00:00        VALLE
# 136339  12513                                                NaN          NaN
# 136340  12514  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
# 136341  12515                Elaboró: PT. Andrés Felipe Taborda           NaN
# 136342  12516               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#             municipio      dia      hora                     barrio    zona  \
# 0               AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
# 1          COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
# 2       MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
# 3       MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4       MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...               ...      ...       ...                        ...     ...
# 136338          TULUÁ   Martes  23:50:00              Villa Liliana  URBANA
# 136339            NaN      NaN       NaN                        NaN     NaN
# 136340            NaN      NaN       NaN                        NaN     NaN
# 136341            NaN      NaN       NaN                        NaN     NaN
# 136342            NaN      NaN       NaN                        NaN     NaN
#
#                             clase_de_sitio  arma_empleada  ... movil_victima  \
# 0                       FINCAS Y SIMILARES    ARMA BLANCA  ...         A PIE
# 1       FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO  ...         A PIE
# 2                            VIAS PUBLICAS  ARMA DE FUEGO  ...         A PIE
# 3                    ESCENARIOS DEPORTIVOS  ARMA DE FUEGO  ...         A PIE
# 4                    ESCENARIOS DEPORTIVOS  ARMA DE FUEGO  ...         A PIE
# ...                                    ...            ...  ...           ...
# 136338                       VIAS PUBLICAS  ARMA DE FUEGO  ...         A PIE
# 136339                                 NaN            NaN  ...           NaN
# 136340                                 NaN            NaN  ...           NaN
# 136341                                 NaN            NaN  ...           NaN
# 136342                                 NaN            NaN  ...           NaN
#
#        edad       sexo estado_civil pais_de_nacimiento    clase_de_empleado  \
# 0        49  MASCULINO       CASADO           COLOMBIA  EMPLEADO PARTICULAR
# 1        32  MASCULINO  UNION LIBRE           COLOMBIA        INDEPENDIENTE
# 2        33  MASCULINO  UNION LIBRE           COLOMBIA          DESEMPLEADO
# 3        23  MASCULINO      SOLTERO           COLOMBIA           ESTUDIANTE
# 4        23  MASCULINO      SOLTERO           COLOMBIA  EMPLEADO PARTICULAR
# ...     ...        ...          ...                ...                  ...
# 136338   19  MASCULINO  UNION LIBRE           COLOMBIA  EMPLEADO PARTICULAR
# 136339  NaN        NaN          NaN                NaN                  NaN
# 136340  NaN        NaN          NaN                NaN                  NaN
# 136341  NaN        NaN          NaN                NaN                  NaN
# 136342  NaN        NaN          NaN                NaN                  NaN
#
#          profesiones escolaridad codigo_dane  cantidad
# 0       NO REPORTADO    PRIMARIA   5030000.0       NaN
# 1       NO REPORTADO  SECUNDARIA   5212000.0       NaN
# 2       NO REPORTADO  SECUNDARIA   5001000.0       NaN
# 3       NO REPORTADO  SECUNDARIA   5001000.0       NaN
# 4       NO REPORTADO  SECUNDARIA   5001000.0       NaN
# ...              ...         ...         ...       ...
# 136338           NaN  SECUNDARIA  76834000.0       1.0
# 136339           NaN         NaN         NaN   12558.0
# 136340           NaN         NaN         NaN       NaN
# 136341           NaN         NaN         NaN       NaN
# 136342           NaN         NaN         NaN       NaN
#
# [136343 rows x 21 columns]

# %%
df_f.drop(columns=['id'], inplace=True)

# %%
df_f
# Out:
#                                                     fecha departamento  \
# 0                                     2010-01-01 00:00:00    ANTIOQUIA
# 1                                     2010-01-01 00:00:00    ANTIOQUIA
# 2                                     2010-01-01 00:00:00    ANTIOQUIA
# 3                                     2010-01-01 00:00:00    ANTIOQUIA
# 4                                     2010-01-01 00:00:00    ANTIOQUIA
# ...                                                   ...          ...
# 136338                                2019-12-31 00:00:00        VALLE
# 136339                                                NaN          NaN
# 136340  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
# 136341                Elaboró: PT. Andrés Felipe Taborda           NaN
# 136342               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#             municipio      dia      hora                     barrio    zona  \
# 0               AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
# 1          COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
# 2       MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
# 3       MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4       MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...               ...      ...       ...                        ...     ...
# 136338          TULUÁ   Martes  23:50:00              Villa Liliana  URBANA
# 136339            NaN      NaN       NaN                        NaN     NaN
# 136340            NaN      NaN       NaN                        NaN     NaN
# 136341            NaN      NaN       NaN                        NaN     NaN
# 136342            NaN      NaN       NaN                        NaN     NaN
#
#                             clase_de_sitio  arma_empleada movil_agresor  \
# 0                       FINCAS Y SIMILARES    ARMA BLANCA         A PIE
# 1       FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO         A PIE
# 2                            VIAS PUBLICAS  ARMA DE FUEGO         A PIE
# 3                    ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
# 4                    ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
# ...                                    ...            ...           ...
# 136338                       VIAS PUBLICAS  ARMA DE FUEGO     BICICLETA
# 136339                                 NaN            NaN           NaN
# 136340                                 NaN            NaN           NaN
# 136341                                 NaN            NaN           NaN
# 136342                                 NaN            NaN           NaN
#
#        movil_victima edad       sexo estado_civil pais_de_nacimiento  \
# 0              A PIE   49  MASCULINO       CASADO           COLOMBIA
# 1              A PIE   32  MASCULINO  UNION LIBRE           COLOMBIA
# 2              A PIE   33  MASCULINO  UNION LIBRE           COLOMBIA
# 3              A PIE   23  MASCULINO      SOLTERO           COLOMBIA
# 4              A PIE   23  MASCULINO      SOLTERO           COLOMBIA
# ...              ...  ...        ...          ...                ...
# 136338         A PIE   19  MASCULINO  UNION LIBRE           COLOMBIA
# 136339           NaN  NaN        NaN          NaN                NaN
# 136340           NaN  NaN        NaN          NaN                NaN
# 136341           NaN  NaN        NaN          NaN                NaN
# 136342           NaN  NaN        NaN          NaN                NaN
#
#           clase_de_empleado   profesiones escolaridad  codigo_dane  cantidad
# 0       EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA    5030000.0       NaN
# 1             INDEPENDIENTE  NO REPORTADO  SECUNDARIA    5212000.0       NaN
# 2               DESEMPLEADO  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# 3                ESTUDIANTE  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# 4       EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA    5001000.0       NaN
# ...                     ...           ...         ...          ...       ...
# 136338  EMPLEADO PARTICULAR           NaN  SECUNDARIA   76834000.0       1.0
# 136339                  NaN           NaN         NaN          NaN   12558.0
# 136340                  NaN           NaN         NaN          NaN       NaN
# 136341                  NaN           NaN         NaN          NaN       NaN
# 136342                  NaN           NaN         NaN          NaN       NaN
#
# [136343 rows x 20 columns]

# %%
df_f = df_f[df_f.isnull().sum(axis=1) < 5]

# %%
df_f
# Out:
#                       fecha departamento      municipio      dia      hora  \
# 0       2010-01-01 00:00:00    ANTIOQUIA          AMAGÁ  Viernes  14:00:00
# 1       2010-01-01 00:00:00    ANTIOQUIA     COPACABANA  Viernes  08:30:00
# 2       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  02:00:00
# 3       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  11:10:00
# 4       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  11:10:00
# ...                     ...          ...            ...      ...       ...
# 136334  2019-12-31 00:00:00        VALLE     CAICEDONIA   Martes  05:05:00
# 136335  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  20:50:00
# 136336  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  00:20:00
# 136337  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  21:16:00
# 136338  2019-12-31 00:00:00        VALLE          TULUÁ   Martes  23:50:00
#
#                                  barrio    zona  \
# 0                  MALABRIGO PARTE ALTA   RURAL
# 1                       LA MISERICORDIA  URBANA
# 2                      LAS GRANJAS  C-3  URBANA
# 3             ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4             ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...                                 ...     ...
# 136334                  VALLE DEL CAUCA  URBANA
# 136335  VILLA DEL PRADO - EL GUABITO E5  URBANA
# 136336            CIUDADELA FLORALIA E6  URBANA
# 136337         MARIO CORREA RENGIFO E18  URBANA
# 136338                    Villa Liliana  URBANA
#
#                             clase_de_sitio                arma_empleada  \
# 0                       FINCAS Y SIMILARES                  ARMA BLANCA
# 1       FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO
# 2                            VIAS PUBLICAS                ARMA DE FUEGO
# 3                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# 4                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# ...                                    ...                          ...
# 136334                       VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
# 136335                       VIAS PUBLICAS                ARMA DE FUEGO
# 136336                       VIAS PUBLICAS                ARMA DE FUEGO
# 136337              PELUQUERIA Y SIMILARES                ARMA DE FUEGO
# 136338                       VIAS PUBLICAS                ARMA DE FUEGO
#
#                 movil_agresor movil_victima edad       sexo estado_civil  \
# 0                       A PIE         A PIE   49  MASCULINO       CASADO
# 1                       A PIE         A PIE   32  MASCULINO  UNION LIBRE
# 2                       A PIE         A PIE   33  MASCULINO  UNION LIBRE
# 3                       A PIE         A PIE   23  MASCULINO      SOLTERO
# 4                       A PIE         A PIE   23  MASCULINO      SOLTERO
# ...                       ...           ...  ...        ...          ...
# 136334                  A PIE         A PIE   42  MASCULINO      SOLTERO
# 136335                  A PIE         A PIE   36  MASCULINO      SOLTERO
# 136336                  A PIE         A PIE   22  MASCULINO      SOLTERO
# 136337  CONDUCTOR MOTOCICLETA         A PIE   25  MASCULINO      SOLTERO
# 136338              BICICLETA         A PIE   19  MASCULINO  UNION LIBRE
#
#        pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# 0                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 1                COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 2                COLOMBIA          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 3                COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 4                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# ...                   ...                  ...           ...         ...
# 136334           COLOMBIA  EMPLEADO PARTICULAR           NaN    PRIMARIA
# 136335           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136336           COLOMBIA          DESEMPLEADO           NaN    PRIMARIA
# 136337           COLOMBIA        INDEPENDIENTE           NaN    PRIMARIA
# 136338           COLOMBIA  EMPLEADO PARTICULAR           NaN  SECUNDARIA
#
#         codigo_dane  cantidad
# 0         5030000.0       NaN
# 1         5212000.0       NaN
# 2         5001000.0       NaN
# 3         5001000.0       NaN
# 4         5001000.0       NaN
# ...             ...       ...
# 136334   76122000.0       1.0
# 136335   76001000.0       1.0
# 136336   76001000.0       1.0
# 136337   76001000.0       1.0
# 136338   76834000.0       1.0
#
# [136238 rows x 20 columns]

# %%
df_f.isnull().sum()
# Out:
# fecha                     0
# departamento              0
# municipio                 0
# dia                       0
# hora                      0
# barrio                 5067
# zona                      0
# clase_de_sitio            0
# arma_empleada             9
# movil_agresor           627
# movil_victima           453
# edad                     33
# sexo                      0
# estado_civil            585
# pais_de_nacimiento     1577
# clase_de_empleado         0
# profesiones           89584
# escolaridad             768
# codigo_dane               0
# cantidad              46654
# dtype: int64

# %%
df_f.hora = pd.to_datetime(df_f.hora, format='%H:%M:%S')
df_f['year'] = df_f.fecha.dt.year
df_f['hora_int'] = df_f.hora.dt.hour
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_f.edad.replace('NO REPORTADO', np.nan, inplace=True)
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df_f.edad = df_f.edad.astype(float)

# %%
df_f.municipio.replace(' \(CT\)', '', regex=True, inplace=True)
df_f.municipio.replace('BOGOTÁ', 'BOGOTA D.C.', inplace=True)
df_f.municipio.replace('BOGOTÁ D.C.', 'BOGOTA D.C.', inplace=True)
df_f.departamento.replace('BOGOTÁ', 'BOGOTA D.C.', inplace=True)
df_f.departamento.replace('GUAJIRA', 'LA GUAJIRA', inplace=True)
df_f.departamento.replace('VALLE', 'VALLE DEL CAUCA', inplace=True)
df_f.departamento.replace('NARIÑO', 'NARINO', inplace=True)

# %%
for col in df_f.columns:
    print(col)
    print(df_f[col].unique())
# Out:
# fecha
# [datetime.datetime(2010, 1, 1, 0, 0) datetime.datetime(2010, 1, 2, 0, 0)
#  datetime.datetime(2010, 1, 3, 0, 0) ...
#  datetime.datetime(2019, 12, 29, 0, 0)
#  datetime.datetime(2019, 12, 30, 0, 0)
#  datetime.datetime(2019, 12, 31, 0, 0)]
# departamento
# ['ANTIOQUIA' 'ATLÁNTICO' 'BOLÍVAR' 'CALDAS' 'CAQUETÁ' 'CAUCA' 'CESAR'
#  'CUNDINAMARCA' 'LA GUAJIRA' 'GUAVIARE' 'HUILA' 'NARINO' 'QUINDÍO'
#  'RISARALDA' 'SANTANDER' 'SUCRE' 'TOLIMA' 'VALLE DEL CAUCA' 'CASANARE'
#  'CHOCÓ' 'META' 'PUTUMAYO' 'ARAUCA' 'CÓRDOBA' 'NORTE DE SANTANDER'
#  'BOYACÁ' 'MAGDALENA' 'VICHADA' 'SAN ANDRÉS' 'AMAZONAS' 'GUAINÍA' 'VAUPÉS']
# municipio
# ['AMAGÁ' 'COPACABANA' 'MEDELLÍN' 'RIONEGRO' 'BARRANQUILLA' 'MALAMBO'
#  'CARTAGENA' 'MAGANGUÉ' 'MARÍA LA BAJA' 'MOMPÓS' 'MANIZALES' 'SAN JOSÉ'
#  'CARTAGENA DEL CHAIRÁ' 'CURILLO' 'FLORENCIA' 'ARGELIA' 'BALBOA' 'CAJIBÍO'
#  'POPAYÁN' 'SANTANDER DE QUILICHAO' 'PAILITAS' 'BOGOTA D.C.' 'GUADUAS'
#  'RIOHACHA' 'CALAMAR' 'ACEVEDO' 'NEIVA' 'LEIVA' 'PASTO'
#  'SAN ANDRES DE TUMACO' 'TAMINANGO' 'ARMENIA' 'DOSQUEBRADAS' 'LA VIRGINIA'
#  'PEREIRA' 'BUCARAMANGA' 'OCAMONTE' 'TOLÚ VIEJO' 'FLANDES' 'IBAGUÉ' 'CALI'
#  'CARTAGO' 'EL CERRITO' 'FLORIDA' 'GUADALAJARA DE BUGA' 'PALMIRA'
#  'SEVILLA' 'TULUÁ' 'BELLO' 'CALDAS' 'YARUMAL' 'SOLEDAD' 'SOLANO'
#  'PAZ DE ARIPORO' 'PUERTO TEJADA' 'SUÁREZ' 'BAGADÓ' 'PUERTO GAITÁN'
#  'SAMANIEGO' 'PUERTO GUZMÁN' 'SIBUNDOY' 'BARRANCABERMEJA' 'GUACARÍ'
#  'ROLDANILLO' 'TRUJILLO' 'CONCORDIA' 'ARAUQUITA' 'CHINCHINÁ'
#  'SAN VICENTE DEL CAGUÁN' 'CIÉNAGA DE ORO' 'GARZÓN' 'GUAITARILLA'
#  'SALENTO' 'BUENAVENTURA' 'JAMUNDÍ' 'ULLOA' 'ABEJORRAL' 'BETULIA'
#  'SARAVENA' 'ZAMBRANO' 'SAN ALBERTO' 'VALLEDUPAR' 'BAHÍA SOLANO'
#  'TIERRALTA' 'SAN JOSÉ DEL GUAVIARE' 'TÚQUERRES' 'CÚCUTA' 'BUGALAGRANDE'
#  'CANDELARIA' 'LA UNIÓN' 'CÁCERES' 'CAREPA' 'CAUCASIA' 'CISNEROS'
#  'SABANETA' 'ZARAGOZA' 'AQUITANIA' 'HATO COROZAL' 'TADÓ' 'CERETÉ'
#  'MONTERÍA' 'MIRAFLORES' 'FUNDACIÓN' 'VILLAVICENCIO' 'MOCOA' 'COVEÑAS'
#  'SAN MARCOS' 'YUMBO' 'ZARZAL' 'SOPETRÁN' 'TURBO' 'TAME' 'FILADELFIA'
#  'LA DORADA' 'MOÑITOS' 'PURÍSIMA' 'CIÉNAGA' 'SANTA MARTA'
#  'PUERTO SANTANDER' 'APARTADÓ' 'EL CARMEN DE VIBORAL' 'ITAGUI'
#  'PUERTO BERRÍO' 'AGUSTÍN CODAZZI' 'RIOSUCIO' 'PLANETA RICA' 'SAN ANTERO'
#  'AGUA DE DIOS' 'PITAL' 'EL RETÉN' 'CUASPUD' 'RICAURTE' 'CACHIRÁ'
#  'LA ESPERANZA' 'ORITO' 'PUERTO WILCHES' 'YOTOCO' 'CHIGORODÓ' 'TARAZÁ'
#  'LURUACO' 'RISARALDA' 'SAN BERNARDO DEL VIENTO' 'PACHO'
#  'SAN PEDRO DE CARTAGO' 'PUERTO ASÍS' 'QUIMBAYA' 'CHARALÁ' 'CIMITARRA'
#  'SAN ONOFRE' 'ARBOLETES' 'CHINÚ' 'CAJICÁ' 'MAICAO' 'IPIALES' 'EL ZULIA'
#  'SILOS' 'EL DOVIO' 'PRADERA' 'DABEIBA' 'REMEDIOS' 'SANTAFÉ DE ANTIOQUIA'
#  'VITERBO' 'PATÍA' 'GUASCA' 'LA PLATA' 'BUCARASICA' 'LA TEBAIDA' 'APÍA'
#  'CAICEDONIA' 'SANTA BÁRBARA' 'PAYA' 'EL TAMBO' 'ASTREA' 'LORICA'
#  'PUERTO LIBERTADOR' 'ZIPAQUIRÁ' 'PIVIJAY' 'MAPIRIPÁN' 'OCAÑA'
#  'VILLA DEL ROSARIO' 'CALARCA' 'BELÉN DE UMBRÍA' 'SANTIAGO DE TOLÚ'
#  'ANZOÁTEGUI' 'RESTREPO' 'FORTUL' 'CALDONO' 'ACANDÍ' 'LOS PATIOS' 'DAGUA'
#  'MUTATÁ' 'NECHÍ' 'ALMAGUER' 'BUENOS AIRES' 'ALBANIA' 'TORO'
#  'SANTA ROSA DEL SUR' 'LA VEGA' 'MONTELÍBANO' 'LA MESA' 'ACACÍAS'
#  'PUERTO RICO' 'ESPINAL' 'PUERTO CARREÑO' 'SOACHA' 'IQUIRA' 'MONTENEGRO'
#  'CONCEPCIÓN' 'EL BAGRE' 'LA CEJA' 'PAUNA' 'NEIRA' 'MANÍ' 'YOPAL'
#  'GIRARDOT' 'HOBO' 'PALERMO' 'EL BANCO' 'EL TARRA' 'LA PLAYA'
#  'VALLE DEL GUAMUEZ' 'SAN ANDRÉS' 'FLORIDABLANCA' 'OLAYA' 'VILLANUEVA'
#  'CORINTO' 'GUAPI' 'PELAYA' 'PUEBLO BELLO' 'FACATATIVÁ' 'VISTAHERMOSA'
#  'ROBERTO PAYÁN' 'PUERTO CAICEDO' 'VILLAGARZÓN' 'SANTA ROSA DE CABAL'
#  'SAN JUAN DE BETULIA' 'FREDONIA' 'PUERTO LÓPEZ' 'CIRCASIA' 'QUINCHÍA'
#  'PLANADAS' 'EL SANTUARIO' 'ARJONA' 'CALOTO' 'QUIBDÓ' 'CAMPOALEGRE'
#  'SINCELEJO' 'PUERTO NARE' 'SALADOBLANCO' 'GUAMAL' 'SAN BERNARDO'
#  'MONIQUIRÁ' 'LA MONTAÑITA' 'BOLÍVAR' 'MIRANDA' 'ROVIRA' 'HISPANIA'
#  'TURBACO' 'CHIQUINQUIRÁ' 'MANZANARES' 'SEGOVIA' 'MORALES' 'AGUADAS'
#  'PENSILVANIA' 'FUSAGASUGÁ' 'HACARÍ' 'MARSELLA' 'GIRÓN' 'SAMPUÉS'
#  'MARIQUITA' 'SABANAGRANDE' 'QUÍPAMA' 'LÓPEZ' 'TOCANCIPÁ' 'ZONA BANANERA'
#  'TIBÚ' 'CAJAMARCA' 'ANDALUCÍA' 'LA VICTORIA' 'NECOCLÍ' 'ARAUCA'
#  'SOGAMOSO' 'LA MERCED' 'PIEDECUESTA' 'YOLOMBÓ' 'OPORAPA' 'SAN AGUSTÍN'
#  'ENVIGADO' 'GUARNE' 'GUACHENÉ' 'PUEBLO NUEVO' 'GUAYATÁ' 'NEMOCÓN'
#  'PITALITO' 'GRANADA' 'ABREGO' 'TEORAMA' 'URRAO' 'BUENAVISTA' 'CUMBITARA'
#  'SANDONÁ' 'RIOFRÍO' 'YONDÓ' 'PUERTO RONDÓN' 'REPELÓN' 'PALESTINA' 'SUPÍA'
#  'SAN JOSÉ DEL FRAGUA' 'TIMBÍO' 'EL RETORNO' 'TIMANÁ'
#  'SAN VICENTE DE CHUCURÍ' 'PALOCABILDO' 'MARMATO' 'URUMITA' 'ANSERMANUEVO'
#  'PUERTO BOYACÁ' 'PORE' 'LA JAGUA DE IBIRICO' 'COTORRA' 'SAHAGÚN'
#  'DIBULLA' 'ARACATACA' 'BARBOSA' 'TUCHÍN' 'SAN JUAN DE ARAMA' 'SANTA ROSA'
#  'TAMALAMEQUE' 'EL TABLÓN DE GÓMEZ' 'OLAYA HERRERA' 'LA ESTRELLA'
#  'EL CHARCO' 'MARINILLA' 'CANTAGALLO' 'EL PAUJIL' 'MONTERREY' 'ROSAS'
#  'SAN JOSÉ DEL PALMAR' 'PUERTO ESCONDIDO' 'BARRANCAS' 'CUMARIBO'
#  'MOTAVITA' 'ANSERMA' 'VILLA DE SAN DIEGO DE UBATE' 'MALLAMA' 'SAN LUIS'
#  'ITUANGO' 'VILLETA' 'GUARANDA' 'EL ÁGUILA' 'AMALFI' 'CHIMÁ' 'SASAIMA'
#  'BARBACOAS' 'LANDÁZURI' 'MARQUETALIA' 'CÓRDOBA' 'SANTA ROSALÍA'
#  'GUADALUPE' 'SANTA MARÍA' 'AGUACHICA' 'PUENTE NACIONAL' 'EL CAIRO'
#  'DUITAMA' 'PLATO' 'CHINÁCOTA' 'SAN CARLOS' 'BARANOA' 'JUAN DE ACOSTA'
#  'LENGUAZAQUE' 'HATONUEVO' 'ISNOS' 'TELLO' 'SAN ZENÓN' 'ATACO' 'CHAPARRAL'
#  'MAJAGUAL' 'HERVEO' 'YALÍ' 'MERCADERES' 'EL PASO' 'VALENCIA' 'CHIPAQUE'
#  'VALLE DE SAN JUAN' 'LETICIA' 'SABANALARGA' 'PUERTO LLERAS' 'MESETAS'
#  'PUERTO LEGUÍZAMO' 'ARATOCA' 'CHIPATÁ' 'SIMITÍ' 'VILLAMARÍA' 'POLICARPA'
#  'EL CARMEN DE BOLÍVAR' 'MILÁN' 'PEDRAZA' 'LA CELIA' 'COROZAL' 'VICTORIA'
#  'FUNZA' 'SIBATÉ' 'VENECIA' 'NÁTAGA' 'ANORÍ' 'ISTMINA' 'SAN CAYETANO'
#  'BECERRIL' 'VALDIVIA' 'BOSCONIA' 'OIBA' 'ORTEGA' 'POLONUEVO' 'PURACÉ'
#  'LA PAZ' 'SIPÍ' 'EL CARMEN' 'MISTRATÓ' 'SAN JERÓNIMO' 'GALAPA' 'VIOTÁ'
#  'URIBIA' 'LA FLORIDA' 'RAGONVALIA' 'PUERTO TRIUNFO' 'MAHATES' 'OTANCHE'
#  'CONDOTO' 'ALCALÁ' 'UNIÓN PANAMERICANA' 'PARATEBUENO' 'PUERTO SALGAR'
#  'POTOSÍ' 'COROMORO' 'CASABIANCA' 'CAMPAMENTO' 'MUZO' 'SAN PELAYO'
#  'SAN PEDRO' 'SAN JUAN DE URABÁ' 'MEDIO SAN JUAN' 'LOS CÓRDOBAS' 'CAQUEZA'
#  'ALGECIRAS' 'PIJAO' 'SAN PABLO' 'BELALCÁZAR' 'PAMPLONA' 'LA BELLEZA'
#  'AIPE' 'CONVENCIÓN' 'MOGOTES' 'SABANA DE TORRES' 'ZETAQUIRA'
#  'LA ARGENTINA' 'SANTUARIO' 'SAN ANDRÉS DE CUERQUÍA' 'LA APARTADA'
#  'LA TOLA' 'SAN FRANCISCO' 'TUNJA' 'EL DONCELLO' 'VILLAPINZÓN' 'ARMERO'
#  'PEÑOL' 'EL COCUY' 'SAN JOSÉ DE URÉ' 'HONDA' 'OBANDO' 'LA CRUZ' 'LINARES'
#  'PUERTO COLOMBIA' 'SUAZA' 'SAN MARTÍN' 'LA CALERA' 'LA MACARENA' 'URIBE'
#  'ARBELÁEZ' 'FILANDIA' 'APULO' 'GUATEQUE' 'RETIRO' 'TARSO' 'MOMIL'
#  'EL CASTILLO' 'JERICÓ' 'SANTO TOMÁS' 'NUNCHÍA' 'TENJO' 'COELLO' 'CUMBAL'
#  'SANTIAGO' 'SUTATAUSA' 'GUACA' 'OVEJAS' 'PÁCORA' 'GÉNOVA' 'PADILLA'
#  'CURUMANÍ' 'ATRATO' 'BETANIA' 'TUBARÁ' 'EL ROSARIO' 'CARMEN DE APICALÁ'
#  'JENESANO' 'PIENDAMÓ' 'SONSON' 'SAN LUIS DE PALENQUE' 'SUCRE' 'ANDES'
#  'VEGACHÍ' 'COGUA' 'RIVERA' 'CAÑASGORDAS' 'SOCHA' 'MOSQUERA' 'CABRERA'
#  'LÍBANO' 'GAMBITA' 'SAN GIL' 'SANTACRUZ' 'CANALETE' 'AGUAZUL'
#  'CASTILLA LA NUEVA' 'CALIMA' 'DOLORES' 'GIRARDOTA' 'AGRADO' 'BOCHALEMA'
#  'RIOBLANCO' 'SAN JACINTO' 'ALMEIDA' 'MADRID' 'MORROA' 'VIRACACHÁ'
#  'PUERRES' 'SAN JUAN NEPOMUCENO' 'GACHALA' 'PASCA' 'SAN LORENZO'
#  'SARDINATA' 'COYAIMA' 'LA PRIMAVERA' 'ENTRERRIOS' 'YACUANQUER'
#  'PUERTO CONCORDIA' 'SAMANÁ' 'MORELIA' 'EL CARMEN DE CHUCURÍ' 'SITIONUEVO'
#  'CHIRIGUANÁ' 'TARQUI' 'PUEBLOVIEJO' 'VÉLEZ' 'GUAMO' 'PAZ DE RÍO'
#  'EL COLEGIO' 'BELÉN' 'CHOACHÍ' 'VILLAHERMOSA' 'ALTOS DEL ROSARIO'
#  'ALVARADO' 'FRESNO' 'LEJANÍAS' 'SOCORRO' 'NORCASIA' 'NÓVITA'
#  'GÓMEZ PLATA' 'GUÁTICA' 'PRADO' 'TOLEDO' 'MEDIO ATRATO' 'NUQUÍ' 'UNE'
#  'MANAURE' 'SANTO DOMINGO' 'TORIBIO' 'MEDIO BAUDÓ' 'VALPARAÍSO' 'SUSACÓN'
#  'PIAMONTE' 'SAN MIGUEL' 'ANGELÓPOLIS' 'SAN ESTANISLAO' 'CHIMICHAGUA'
#  'FRONTINO' 'EL PEÑOL' 'BRICEÑO' 'DON MATÍAS' 'ANAPOIMA' 'QUEBRADANEGRA'
#  'SESQUILÉ' 'BARRANCO DE LOBA' 'CUBARÁ' 'SAN CALIXTO'
#  'SAN PABLO DE BORBUR' 'CHÍA' 'BUESACO' 'COLÓN' 'LA CUMBRE' 'JAMBALÓ'
#  'ALBÁN' 'PINILLOS' 'ARIGUANÍ' 'SAN BENITO ABAD' 'MACANAL' 'TERUEL'
#  'SAN RAFAEL' 'NOBSA' 'ÚTICA' 'BELÉN DE LOS ANDAQUIES' 'PUEBLO RICO'
#  'PAIPA' 'AYAPEL' 'MELGAR' 'TIQUISIO' 'SAN JUAN DE RÍO SECO' 'RÍO VIEJO'
#  'GIGANTE' 'NARIÑO' 'SOTARA' 'VILLA RICA' 'PUPIALES' 'PALMITO' 'CONSACA'
#  'ONZAGA' 'SOMONDOCO' 'LA PINTADA' 'CUMARAL' 'SALGAR' 'EL GUAMO'
#  'LA GLORIA' 'LA LLANADA' 'RONCESVALLES' 'VERSALLES' 'PALMAR DE VARELA'
#  'SILVIA' 'ALDANA' 'TÁMESIS' 'SAN MARTÍN DE LOBA' 'BOJACÁ' 'TENA'
#  'LEBRIJA' 'SANTA CATALINA' 'BARRANCA DE UPÍA' 'PANDI' 'UNGUÍA' 'FONSECA'
#  'ANGOSTURA' 'TAUSA' 'SANTA BÁRBARA DE PINTO' 'EL COPEY' 'QUIPILE'
#  'SANTA HELENA DEL OPÓN' 'URAMITA' 'VENTAQUEMADA' 'MONTECRISTO' 'TESALIA'
#  'SOCOTÁ' 'SAN ANTONIO' 'TÁMARA' 'EL CANTÓN DEL SAN PABLO' 'ALGARROBO'
#  'LÉRIDA' 'SALDAÑA' 'SABOYÁ' 'TAURAMENA' 'NIMAIMA' 'SAN LUIS DE SINCÉ'
#  'BELMIRA' 'CIUDAD BOLÍVAR' 'UMBITA' 'SOLITA' 'BAJO BAUDÓ' 'SANTA ANA'
#  'CABUYARO' 'SIMACOTA' 'CAPARRAPÍ' 'SÁCAMA' 'SUPATÁ' 'CHACHAGÜÍ'
#  'TITIRIBÍ' 'GARAGOA' 'COCORNÁ' 'SILVANIA' 'AMBALEMA' 'CAMPOHERMOSO'
#  'GUATAQUÍ' 'SAN ANDRÉS SOTAVENTO' 'VIANÍ' 'VENADILLO' 'SIMIJACA'
#  'CHITAGÁ' 'ARANZAZU' 'GUACHUCAL' 'CHIVATÁ' 'JORDÁN' 'EL PEÑÓN'
#  'PUEBLORRICO' 'RÍO DE ORO' 'SAN ANTONIO DEL TEQUENDAMA' 'LA CAPILLA'
#  'SAN SEBASTIÁN' 'PEQUE' 'GÜICÁN' 'PULÍ' 'INZÁ' 'NOCAIMA' 'PALMAR'
#  'EL ROBLE' 'PROVIDENCIA' 'SAMACÁ' 'TIMBIQUÍ' 'FUENTE DE ORO' 'TOTORÓ'
#  'TRINIDAD' 'GACHANCIPÁ' 'SOPÓ' 'NILO' 'FLORIÁN' 'SANTA ROSA DE OSOS'
#  'GUTIÉRREZ' 'OSPINA' 'OROCUÉ' 'VIGÍA DEL FUERTE' 'YACOPÍ' 'TUTA'
#  'GINEBRA' 'INÍRIDA' 'DISTRACCIÓN' 'FRANCISCO PIZARRO' 'CAICEDO'
#  'MOLAGAVITA' 'SUTATENZA' 'ANCUYÁ' 'SAN JOSÉ DE MIRANDA' 'TOCAIMA'
#  'NUEVA GRANADA' 'SAN LUIS DE GACENO' 'TURBANÁ' 'PAIME' 'CARCASÍ'
#  'SAN DIEGO' 'CONTADERO' 'SANTANA' 'PÁRAMO' 'PUERTO PARRA'
#  'SAN JUAN DEL CESAR' 'YAGUARÁ' 'GÜEPSA' 'SAN VICENTE' 'SUESCA' 'BARAYA'
#  'MACEO' 'ACHÍ' 'EBÉJICO' 'BURITICÁ' 'COTA' 'GUACHETÁ' 'MEDINA' 'VIJES'
#  'CHITA' 'HELICONIA' 'MARGARITA' 'ANZA' 'LIBORINA' 'SABANAS DE SAN ANGEL'
#  'CURITÍ' 'MARIPÍ' 'CHIMA' 'CHOCONTÁ' 'TANGUA' 'FALAN' 'MATANZA' 'CÓMBITA'
#  'CACHIPAY' 'SAN ROQUE' 'CHINAVITA' 'NATAGAIMA' 'ZAPAYÁN' 'GALÁN' 'NOROSÍ'
#  'BOAVITA' 'FOSCA' 'VILLAVIEJA' 'EL ROSAL' 'ALTO BAUDÓ' 'COLOMBIA'
#  'SALAZAR' 'SUAITA' 'GUAYABETAL' 'TABIO' 'VILLAGÓMEZ' 'CUBARRAL'
#  'SAN MIGUEL DE SEMA' 'ILES' 'SAN JOAQUÍN' 'CUCUNUBÁ' 'CARMEN DE CARUPA'
#  'TENERIFE' 'CRAVO NORTE' 'SAN PEDRO DE URABÁ' 'SUBACHOQUE' 'PAEZ' 'MAGÜI'
#  'SALAMINA' 'TIBACUY' 'GUATAVITA' 'CÉRTEGUI' 'LA SIERRA' 'ANOLAIMA'
#  'FOMEQUE' 'ZAPATOCA' 'CAIMITO' 'SAN JOSÉ DE PARE' 'EL CARMEN DE ATRATO'
#  'CICUCO' 'CLEMENCIA' 'GACHETÁ' 'ZIPACÓN' 'SAN JACINTO DEL CAUCA'
#  'RÁQUIRA' 'BELTRÁN' 'GUALMATÁN' 'TOTA' 'TIBIRITA' 'ICONONZO' 'GIRALDO'
#  'FUNES' 'TINJACÁ' 'PINCHOTE' 'CHITARAQUE' 'LA PEÑA' 'ARROYOHONDO'
#  'GALERAS' 'QUETAME' 'PAICOL' 'SAN CARLOS DE GUAROA' 'UBALÁ' 'ARBOLEDA'
#  'MURILLO' 'CARMEN DEL DARIEN' 'MONTEBELLO' 'MURINDÓ' 'VILLA DE LEYVA'
#  'SANTA ISABEL' 'MACHETA' 'RECETOR' 'SORACÁ' 'LOURDES' 'PIOJÓ' 'EL PLAYÓN'
#  'GONZÁLEZ' 'TONA' 'PURIFICACIÓN' 'ALTAMIRA' 'EL MOLINO' 'RÍO IRO'
#  'SAN SEBASTIÁN DE BUENAVISTA' 'LABATECA' 'SIACHOQUE' 'PONEDERA'
#  'LA SALINA' 'CHÍQUIZA' 'LOS ANDES' 'REGIDOR' 'SAN MATEO' 'PUERTO NARIÑO'
#  'MITÚ' 'SANTA SOFÍA' 'MÁLAGA' 'GAMEZA' 'MANTA' 'VILLA CARO' 'ARCABUCO'
#  'ARBOLEDAS' 'TASCO' 'TOGÜÍ' 'VERGARA' 'CONFINES' 'MANATÍ' 'LLORÓ'
#  'TOPAIPÍ' 'CUNDAY' 'PIEDRAS' 'TUNUNGUÁ' 'ENCINO' 'LOS SANTOS' 'SOTAQUIRÁ'
#  'LOS PALMITOS' 'JURADÓ' 'LABRANZAGRANDE' 'CERRITO' 'GUATAPÉ' 'SOATÁ'
#  'PÁEZ' 'ENCISO' 'JARDÍN' 'PALMAS DEL SOCORRO' 'SAPUYES' 'CAPITANEJO'
#  'VILLARRICA' 'CAROLINA' 'BOJAYÁ' 'PAJARITO' 'CARAMANTA' 'TOCA'
#  'CONTRATACIÓN' 'CUÍTIVA' 'ARENAL' 'ELÍAS' 'CHIBOLO' 'VALLE DE SAN JOSÉ'
#  'COPER' 'LA UVITA' 'PESCA' 'IMUÉS' 'VETAS' 'CARACOLÍ' 'CUCAITA' 'CHAMEZA'
#  'FIRAVITOBA' 'GAMARRA' 'EL LITORAL DEL SAN JUAN' 'TIBANÁ' 'LA PALMA'
#  'DURANIA' 'SUTAMARCHÁN' 'EL PIÑON' 'SAN EDUARDO' 'PAMPLONITA' 'RÍO QUITO'
#  'CUCUTILLA' 'TIBASOSA' 'USIACURÍ' 'GUAYABAL DE SIQUIMA' 'ALEJANDRÍA'
#  'CERINZA' 'CHAGUANÍ' 'REMOLINO' 'RAMIRIQUÍ' 'MARULANDA'
#  'CAMPO DE LA CRUZ' 'CERRO SAN ANTONIO' 'CHISCAS' 'JERUSALÉN' 'SUAN'
#  'TUTAZÁ' 'JESÚS MARÍA' 'EL DORADO' 'CHARTA' 'CÁCOTA' 'MONGUA'
#  'LA JAGUA DEL PILAR' 'CHALÁN' 'JUNÍN' 'SANTA ROSA DE VITERBO'
#  'TALAIGUA NUEVO' 'COLOSO' 'TARAIRA' 'MONGUÍ' 'SAN BENITO' 'BITUIMA'
#  'OICATÁ' 'GRAMALOTE' 'TURMEQUÉ' 'BARICHARA' 'HATILLO DE LOBA' 'SURATÁ'
#  'GUAVATÁ' 'GUAPOTÁ' 'PIJIÑO DEL CARMEN' 'TÓPAGA' 'SUSA' 'GACHANTIVÁ'
#  'PANQUEBA' 'MUTISCUA' 'SAN FERNANDO' 'COVARACHÍA' 'TIPACOQUE' 'CARURU'
#  'SÁCHICA' 'NUEVO COLÓN' 'HERRÁN' 'SAN JOSÉ DE LA MONTAÑA' 'ABRIAQUÍ'
#  'PACHAVITA' 'SORA' 'HATO' 'BOYACÁ' 'PISBA' 'ALPUJARRA' 'SAN CRISTÓBAL']
# dia
# ['Viernes' 'Sábado' 'Domingo' 'Lunes' 'Martes' 'Miércoles' 'Jueves']
# hora
# ['1900-01-01T14:00:00.000000000' '1900-01-01T08:30:00.000000000'
#  '1900-01-01T02:00:00.000000000' ... '1900-01-01T06:51:00.000000000'
#  '1900-01-01T04:31:00.000000000' '1900-01-01T07:04:00.000000000']
# barrio
# ['MALABRIGO PARTE ALTA' 'LA MISERICORDIA' 'LAS GRANJAS  C-3' ...
#  'LA OVEJERIA' 'VEREDA EL LORITO' 'CGTO CERRO AZUL']
# zona
# ['RURAL' 'URBANA']
# clase_de_sitio
# ['FINCAS Y SIMILARES' 'FRENTE A RESIDENCIAS - VIA PUBLICA' 'VIAS PUBLICAS'
#  'ESCENARIOS DEPORTIVOS' 'CASAS DE HABITACION' 'BODEGAS Y SIMILARES'
#  'ESTADERO' 'PARQUES' 'DENTRO DE LA VIVIENDA' 'POTREROS'
#  'CENTRO COMERCIAL' 'HOSPITALES' 'PLAZAS DE MERCADO' 'LOCAL COMERCIAL'
#  'DISCOTECAS' 'RIOS' 'TIENDA' 'SOBRE ANDEN - VIA PUBLICA'
#  'SECTOR COMERCIO' 'INTERIOR VEHICULO SERVICIO PUBLICO' 'TROCHA'
#  'CEMENTERIO' 'TALLERES' 'ESTACIONES DE SERVICIO'
#  'FRENTE EMPRESA - VIA PUBLICA' 'BARES, CANTINAS Y SIMILARES'
#  'PARADERO DE BUSES' 'PANADERIAS' 'CARRETERA' 'BILLARES'
#  'INSTALACIONES DEL EJERCITO' 'CANCHA DE FUTBOL' 'SUPERMERCADOS'
#  'INTERIOR VEHICULO PARTICULAR' 'COLEGIOS, ESCUELAS' 'CAÑOS' 'SELVA'
#  'LOTE BALDIO' 'FRENTE A COLEGIO - VIA PUBLICA' 'RIVERAS'
#  'PERIMETRO URBANO' 'RODANDO SOBRE VIA - VIA PUBLICA'
#  'HOTELES, RESIDENCIAS, Y SIMILARES.' 'TALLERES MECANICA'
#  'INSTALACIONES DE LA POLICIA' 'FRENTE A ALMACEN - VIA PUBLICA'
#  'RESTAURANTES' 'BOMBA DE GASOLINA'
#  'FRENTE CLINICA U HOSPITAL - VIA PUBLICA' 'NO DEFINIDO'
#  'FRENTE RESTAURANTE' 'PUESTO DE CONTROL' 'TRAMO DE VIA' 'CAFETERIAS'
#  'ALMACENES' 'FRENTE CENTRO COMERCIAL' 'CANCHAS DE RANA'
#  'CONJUNTO RESIDENCIAL' 'BANCOS' 'FRENTE IGLESIA - VIA PUBLICA'
#  'SALON COMUNAL' 'PELUQUERIA Y SIMILARES' 'LINEA FERREA' 'QUEBRADA'
#  'GLORIETA' 'SALON JUEGO DIVERSION' 'MATADEROS, CARNICERIA Y SIMILARES'
#  'REPRESAS' 'LAVA-AUTOS' 'DROGUERIAS, FARMACIAS' 'FRENTE A DISCOTECAS'
#  'FRENTE CONJUNTO - VIA PUBLICA' 'CARCELES'
#  'FRENTE A EDIFICIO - VIA PUBLICA' 'PUENTE' 'CONSTRUCCION'
#  'FRENTE OFICINA' 'CAFE INTERNET' 'ZONA SELVÁTICA' 'CENTRO RECREACIONAL'
#  'TERMINAL DE TRANSPORTES' 'EMPRESA' 'HACIENDA' 'PARQUEADERO' 'CASINOS'
#  'APARTAMENTO' 'FRENTE A BANCO - VIA PUBLICA' 'OFICINAS' 'HELADERIA'
#  'FUNERARIA' 'PISTAS CLANDESTINAS' 'CANCHAS DE TEJO'
#  'CLINICAS Y SIMILARES' 'AEROPUERTO' 'GRANEROS' 'FONDAS' 'GIMNASIO'
#  'PUERTO' 'RANCHERIA' 'ALTAMAR' 'ESTADIO' 'POZO' 'SENDERO PEATONAL'
#  'PLAYA' 'CALLEJÓN' 'CASA DE LENOCINIO' 'LAGUNAS' 'MUELLE'
#  'SECTOR INDUSTRIA' 'MAR' 'SEDES SOCIALES, CLUBES O SIMILARES' 'VEHICULO'
#  'LAVANDERIAS' 'CASA EN CONJUNTO CERRADO' 'SECTOR RESIDENCIAS'
#  'PUENTE PEATONAL' 'COLISEO' 'PLAZA DE TOROS' 'CENTROS RELIGIOSOS'
#  'TRANSPORTE PÚBLICO' 'ESTACION DEL METRO' 'CENTRO TURÍSTICO'
#  'CASETA VIGILANCIA CONJUNTO RESIDENCIAL' 'AUDITORIOS' 'COMPRAVENTA'
#  'CABAÑA' 'PISCINA' 'ISLA' 'GARAJE' 'ESTABLECIMIENTOS REVISADOS'
#  'CASETA VIGILANCIA EMPRESAS' 'INSTALACIONES DE ARMADA NACIONAL'
#  'ALCALDIA' 'FABRICAS' 'RESGUARDO INDÍGENA' 'HUMEALES' 'UNIVERSIDADES'
#  'MONTALLANTAS' 'TALLERES LATONERIA' 'APARTAMENTO EN CONJUNTO CERRADO'
#  'CONSULTORIOS MEDICOS' 'TIPO EXPLOTACIÓN ESMERALDA'
#  'CONSULTORIOS JURIDICOS' 'CASAS DE APUESTAS' 'TIPO EXPLOTACIÓN CARBON'
#  'ALIMENTADOR BUS M.I.O.' 'CAMPAMENTO FARC' 'FOSA COMUN'
#  'TRANSPORTE FLUVIAL' 'ESTACION TRANSMILENIO (INICIAL)' 'CANALIZACION'
#  'FOSA INDIVIDUAL' 'TIPO EXPLOTACIÓN ARENA' 'CONSULTORIOS  ODONTOLOGICOS'
#  'CICLO RUTA' 'TEMPLOS' 'FRUTERIA' 'TANQUE DE AGUA' 'JOYERIAS' 'SEMÁFORO'
#  'ALIMENTADOR BUS TRANSMETRO' 'CAÑADUZAL' 'HOGAR DE PASO' 'BUS METROLINEA'
#  'TALLERES ELECTRICIDAD' 'INSTALACIONES GUBERNAMENTALES'
#  'INSTALACIONES DE FUERZA AREA' 'BAHIA' 'LICORERA/ESTANCO 24 HORAS'
#  'TIPO EXPLOTACIÓN ORO' 'ESTACION M.I.O.' 'MUELLE TURISTICO' 'GALLERA'
#  'TRANSPORTE ESCOLAR' 'BUS METROPLUS' 'DESGUAZADERO' 'MINA' 'BOSQUES'
#  'INSTALACIONES JUDICIALES' 'CASETA COMUNAL' 'INTERIOR VEHICULO SITP'
#  'CULTIVOS' 'IGLESIA' 'FERRERERAS, MARRANERAS Y CABALLERIZAS'
#  'PATOLOGIA-MORGUE' 'ALOJAMIENTO' 'FRONTERA'
#  'ESTACION TRANSMILENIO BICENTENARIO' 'ESTACION TRANSMILENIO AV. JIMENEZ'
#  'ESTACION TRANSMILENIO BIB. EL TINTAL' 'BUS TRANSMILENIO' 'BAÑOS'
#  'FERIA GANADO' 'PEAJE' 'INTERIOR VEHICULO PONAL'
#  'ESTACION TRANSMILENIO CALLE 106' 'ESTACION TRANSMILENIO CALLE 19'
#  'ESTACION TRANSMILENIO PATIO BONITO' 'BUS MEGABUS' 'ESTACION MEGABUS'
#  'COMEDORES Y/O COCINA' 'SALA DE RETENIDOS'
#  'BUS MASIVO INTEGRAL DE OCCIDENTE M.I.O.'
#  'ESTACION TRANSMILENIO RICAURTE (CRA 30)' 'ESCALERAS FIJAS' 'BIBLIOTECA'
#  'ESTABLECIMIENTO PUBLICO' 'ESTABLECIMIENTO DE COMERCIO' 'VEHICULO TAXI'
#  'ESTACION TRANSMILENIO LAS FERIAS' 'OTRO' 'ESTACION TRANSMILENIO MOLINOS'
#  'GOBERNACION' 'ZONAS AZULES - VIA PUBLICA' 'TRANSPORTE INTERMUNICIPAL'
#  'CAJERO AUTOMATICO' 'LUGAR DE TRABAJO' 'LUGAR DE EVENTOS' 'GARITA'
#  'TRANSPORTE PUBLICO URBANO' 'VELODROMO' 'VEHICULO BEAT'
#  'ESTACION TRANSMILENIO UNIVERSIDADES' 'EMISORAS' 'CORREDORES FLUVIALES'
#  'ESTACION TRANSMILENIO CALLE 45' 'EDIFICIO' 'VEHICULO INDRIVER']
# arma_empleada
# ['ARMA BLANCA' 'ARMA DE FUEGO' 'PUNZANTES' 'CORTANTES' 'CONTUNDENTES'
#  'ARTEFACTO EXPLOSIVO/CARGA DINAMITA' 'MINA ANTIPERSONA'
#  'CUERDA/SOGA/CADENA' 'GASOLINA' 'BOLSA PLASTICA' 'MOTO BOMBA'
#  'GRANADA DE MANO' 'PAQUETE BOMBA' 'SUSTANCIAS TOXICAS'
#  'SIN EMPLEO DE ARMAS' 'JERINGA' 'CARRO BOMBA' 'PERSONA BOMBA' 'CINTAS'
#  'NO REPORTADO' 'ESCOPOLAMINA' 'ALMOHADA' 'CILINDRO BOMBA'
#  'ARTEFACTO INCENDIARIO' 'VENENO' 'ROCKET' 'QUIMICOS' 'OLLA BOMBA' 'GASES'
#  'GRANADA DE MORTERO' 'CASA BOMBA' 'ARMA BLANCA / CORTOPUNZANTE'
#  'COMBUSTIBLE' 'MEDICAMENTOS' 'ACIDO' nan 'CINTAS/CINTURON'
#  'POLVORA(FUEGOS PIROTECNICOS)' 'PRENDAS DE VESTIR' 'LIQUIDOS']
# movil_agresor
# ['A PIE' 'NO REPORTADO' 'VEHICULO' 'CONDUCTOR MOTOCICLETA' 'PASAJERO BUS'
#  'CONDUCTOR TAXI' 'BICICLETA' 'PASAJERO TAXI' 'PASAJERO MOTOCICLETA' nan
#  'CONDUCTOR VEHICULO' 'CONDUCTOR BUS' 'PASAJERO VEHICULO' 'PASAJERO BARCO'
#  'PASAJERO AERONAVE' 'PASAJERO METRO']
# movil_victima
# ['A PIE' 'NO REPORTADO' 'CONDUCTOR MOTOCICLETA' 'VEHICULO'
#  'CONDUCTOR TAXI' 'BICICLETA' 'PASAJERO BUS' 'PASAJERO TAXI'
#  'CONDUCTOR VEHICULO' nan 'PASAJERO MOTOCICLETA' 'CONDUCTOR BUS'
#  'PASAJERO VEHICULO' 'PASAJERO BARCO' 'PASAJERO METRO']
# edad
# [ 49.  32.  33.  23.  51.  25.  27.  40.  42.  22.  34.  41.  21.  30.
#   18.  26.  39.  55.  24.  20.  16.  17.  45.  37.  47.  28.  61.  38.
#   56.  35.  44.  15.  43.  80.  46.  19.  36.  63.  48.  54.  31.  29.
#   72.  50.  58.  57.  90.  53.  13.  60.  59.  66.  67.  14.  65.  75.
#    7.  52.  68.  70.  73.  69.  76.  77.   6.  10.  64.  62.  78.  12.
#   87.  83.   3.  11.  79.  71.  81.  91.   8.   1.   9.  84.   2.  nan
#   82.  74.   5.  86.   4.  85.  92.   0.  89.  88.  94.  95.  93. 100.
#   98.]
# sexo
# ['MASCULINO' 'FEMENINO' 'NO REPORTA']
# estado_civil
# ['CASADO' 'UNION LIBRE' 'SOLTERO' 'SEPARADO' 'NO REPORTA' 'VIUDO'
#  'NO REPORTADO' 'DIVORCIADO' nan]
# pais_de_nacimiento
# ['COLOMBIA' 'NO REPORTADO' 'ECUADOR' 'INGLATERRA' 'VENEZUELA' 'PERU'
#  'JAPON' 'PANAMA' 'ARMENIA' 'ESTADOS UNIDOS' 'CUBA' 'CHILE' 'MEXICO'
#  'LIBANO' 'ESPAÑA' 'BRASIL' 'RUSIA' 'CHINA' 'ITALIA' 'LITUANIA' nan
#  'UCRANIA' 'ANDORRA' 'HOLANDA' 'REPUBLICA DOMINICANA' 'ALEMANIA'
#  'GUINEA-BISSAU' 'TOGO' 'HAITI' 'COSTA RICA' 'ISRAEL' 'DINAMARCA'
#  'PAISES BAJOS' 'TURQUIA' 'TANZANIA' 'FRANCIA' 'SALVADOR' 'AUSTRALIA'
#  'SUECIA' 'ARGENTINA' 'NORUEGA' 'CANADA' 'URUGUAY']
# clase_de_empleado
# ['EMPLEADO PARTICULAR' 'INDEPENDIENTE' 'DESEMPLEADO' 'ESTUDIANTE'
#  'DELINCUENCIA' 'COMERCIANTE' 'NO REPORTA' 'AGRICULTOR' 'AMA DE CASA'
#  'EMPLEADO PUBLICO' 'GRUPOS ILEGALES' 'GANADERO' 'PENSIONADO' 'EDUCADOR'
#  'EMPLEADO POLICIAL' 'ETNIA INDIGENA' 'SECTOR IND' 'EMPLEADO EJERCITO'
#  'LIDER CIVICO' 'SINDICALISTA' 'POLITICO' 'EMPLEADO SALUD' 'EMPLEADO CTI'
#  'RAMA JUDICIAL' 'DEPORTISTA' 'EMPLEADO ARMADA/MARINA' 'EMPLEADO DAS'
#  'RELIGIOSO' 'CANDIDATOS' 'ARTISTA' 'MIEMBRO ONG' 'SECTOR FINANCIERO'
#  'AFRODESCENDIENTE' 'EMPLEADO INPEC' 'FUERZA AEREA']
# profesiones
# ['NO REPORTADO' 'NO REPORTADA' 'TECNOLOGO EN SANEAMIENTO DE SALUD'
#  'POLICIA' 'TECNICO EN SISTEMAS' 'ODONTOLOGO' 'ABOGADO' 'ENFERMERA JEFE'
#  'PILOTO' 'INGENIERO' 'DISEÑADOR' 'INGENIERO INDUSTRIAL' 'TECNICO'
#  'CONTADOR' 'CONTADOR PUBLICO' 'COMUNICADOR SOCIALNO REPORTADOPERIODISTA'
#  'LICENCIADO' 'INGENIERO DE SISTEMAS' 'FISICO' 'ADMINISTRADOR DE EMPRESAS'
#  'QUIMICO' 'INGENIERO CIVIL' 'TECNICO ELECTRICO' 'BACTERIOLOGO' 'ECOLOGO'
#  'ZOOTECNICO' 'POLITOLOGO' 'ADMINISTRADOR HOTELERO' 'INGENIERO AGRONOMO'
#  'ADMINISTRADOR PUBLICO' 'ADMINISTRADOR AGROPECUARIO' 'ARQUITECTO'
#  'MEDICO VETERINARIO' 'MEDICO' 'PSICOLOGO' 'GUARDIAN' 'AUXILIAR DE VUELO'
#  'TECNICO ELECTRICISTA' 'NUTRICIONISTA' 'FISIOTERAPEUTA'
#  'TECNOLOGO OBRAS CIVILES' 'ADMINISTRADOR INMOBILIARIO'
#  'INGENIERO MECANICO' 'INFECTOLOGO' 'FILOSOFO' 'TECNOLOGO'
#  'TECNICO EN ELECTRONICA' 'TOPOGRAFO' 'NEUROCIRUJANO'
#  'INGENIERO ELECTRICO' 'PSIQUIATRA' 'ADMINISTRADOR AGROINDUSTRIAL'
#  'INGENIERO DE PRODUCCION' 'INGENIERO ELECTRICISTA' 'AGRONOMO'
#  'ECONOMISTA' nan]
# escolaridad
# ['PRIMARIA' 'SECUNDARIA' 'TECNICO' 'NO REPORTADO' 'SUPERIOR' 'ANALFABETA'
#  'TECNOLOGO' nan]
# codigo_dane
# [ 5030000.  5212000.  5001000. ... 15550000. 73024000. 13620000.]
# cantidad
# [nan  1.  2.  3. 14.  4.  5.  7.]
# year
# [2010 2011 2012 2013 2014 2015 2016 2017 2018 2019]
# hora_int
# [14  8  2 11 16 20 21 17  1  9  5  6  7  0  3 10  4 13 19 15 23 22 18 12]

# %% [markdown]
# ## Solo Bogotá:

# %%
df_f = df_f[df_f['municipio'] == 'BOGOTA D.C.']

# %%
df_f
# Out:
#                       fecha  departamento    municipio      dia  \
# 29      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 30      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 31      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 32      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 33      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# ...                     ...           ...          ...      ...
# 136284  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136285  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136310  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136311  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136312  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
#
#                       hora                 barrio    zona clase_de_sitio  \
# 29     1900-01-01 00:10:00   SANTA CECILIA I E-11  URBANA  VIAS PUBLICAS
# 30     1900-01-01 01:27:00      VILLA GLORIA E-19  URBANA  VIAS PUBLICAS
# 31     1900-01-01 02:22:00       LA FAVORITA E-14  URBANA  VIAS PUBLICAS
# 32     1900-01-01 03:17:00        QUIRIGUA I E-10  URBANA  VIAS PUBLICAS
# 33     1900-01-01 03:56:00    SANTA ROSA SUR E-19  URBANA  VIAS PUBLICAS
# ...                    ...                    ...     ...            ...
# 136284 1900-01-01 16:46:00        EL PARAISO E-19  URBANA  VIAS PUBLICAS
# 136285 1900-01-01 18:36:00          SANTA FE E-14  URBANA  VIAS PUBLICAS
# 136310 1900-01-01 22:00:00       LA FAVORITA E-14  URBANA  VIAS PUBLICAS
# 136311 1900-01-01 23:45:00  FONTANAR DEL RIO E-11  URBANA  VIAS PUBLICAS
# 136312 1900-01-01 15:24:00     SAN BERNARDINO E-7  URBANA  VIAS PUBLICAS
#
#                       arma_empleada movil_agresor  ...       sexo  \
# 29                      ARMA BLANCA         A PIE  ...  MASCULINO
# 30                      ARMA BLANCA         A PIE  ...  MASCULINO
# 31                      ARMA BLANCA         A PIE  ...  MASCULINO
# 32                    ARMA DE FUEGO         A PIE  ...  MASCULINO
# 33                    ARMA DE FUEGO         A PIE  ...   FEMENINO
# ...                             ...           ...  ...        ...
# 136284  ARMA BLANCA / CORTOPUNZANTE         A PIE  ...  MASCULINO
# 136285                ARMA DE FUEGO         A PIE  ...  MASCULINO
# 136310  ARMA BLANCA / CORTOPUNZANTE         A PIE  ...  MASCULINO
# 136311  ARMA BLANCA / CORTOPUNZANTE         A PIE  ...  MASCULINO
# 136312  ARMA BLANCA / CORTOPUNZANTE         A PIE  ...  MASCULINO
#
#         estado_civil pais_de_nacimiento    clase_de_empleado   profesiones  \
# 29           SOLTERO           COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO
# 30           SOLTERO           COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO
# 31           SOLTERO            ECUADOR  EMPLEADO PARTICULAR  NO REPORTADO
# 32           SOLTERO           COLOMBIA           ESTUDIANTE  NO REPORTADO
# 33           SOLTERO           COLOMBIA        INDEPENDIENTE  NO REPORTADO
# ...              ...                ...                  ...           ...
# 136284       SOLTERO           COLOMBIA        INDEPENDIENTE           NaN
# 136285       SOLTERO           COLOMBIA        INDEPENDIENTE           NaN
# 136310       SOLTERO           COLOMBIA        INDEPENDIENTE           NaN
# 136311   UNION LIBRE           COLOMBIA        INDEPENDIENTE           NaN
# 136312   UNION LIBRE           COLOMBIA          DESEMPLEADO           NaN
#
#        escolaridad codigo_dane cantidad  year  hora_int
# 29      SECUNDARIA  11001000.0      NaN  2010         0
# 30      SECUNDARIA  11001000.0      NaN  2010         1
# 31      SECUNDARIA  11001000.0      NaN  2010         2
# 32      SECUNDARIA  11001000.0      NaN  2010         3
# 33      SECUNDARIA  11001000.0      NaN  2010         3
# ...            ...         ...      ...   ...       ...
# 136284  SECUNDARIA  11001000.0      1.0  2019        16
# 136285  SECUNDARIA  11001000.0      1.0  2019        18
# 136310  SECUNDARIA  11001000.0      1.0  2019        22
# 136311  SECUNDARIA  11001000.0      1.0  2019        23
# 136312  SECUNDARIA  11001000.0      1.0  2019        15
#
# [12653 rows x 22 columns]

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 14
# mpl.rcParams.keys()
sns.set_palette('Accent')

# %%
df_f.barrio.unique()
# Out:
# array(['SANTA CECILIA I E-11', 'VILLA GLORIA E-19', 'LA FAVORITA E-14',
#        ..., 'AVORIAZ E-1', 'LAS ORQUIDEAS E-1', 'FONTANAR DEL RIO E-11'],
#       dtype=object)

# %%
df_f.arma_empleada.replace('ARMA BLANCA / CORTOPUNZANTE', 'ARMA BLANCA', inplace=True)
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %% [markdown]
# ## Maps of counts

# %%
import json

with open('./data/geojson_departamentos.json', 'r') as f:
    departamentos = json.load(f)
    
areas = pd.read_json('./data/areas_departamentos.json',
                     orient='index')
# with open('./data/geoJson_departamentos.json', 'w') as f:
#     json.dump(departamentos, f)

# with open('./data/areas_departamentos.json', 'w') as f:
#     json.dump(areas, f)

# %%
import plotly.express as px

# %%
df_f.departamento = df_f.departamento.apply(unidecode)
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_f
# Out:
#                       fecha  departamento    municipio      dia  \
# 29      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 30      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 31      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 32      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 33      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# ...                     ...           ...          ...      ...
# 136284  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136285  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136310  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136311  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136312  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
#
#                       hora                 barrio    zona clase_de_sitio  \
# 29     1900-01-01 00:10:00   SANTA CECILIA I E-11  URBANA  VIAS PUBLICAS
# 30     1900-01-01 01:27:00      VILLA GLORIA E-19  URBANA  VIAS PUBLICAS
# 31     1900-01-01 02:22:00       LA FAVORITA E-14  URBANA  VIAS PUBLICAS
# 32     1900-01-01 03:17:00        QUIRIGUA I E-10  URBANA  VIAS PUBLICAS
# 33     1900-01-01 03:56:00    SANTA ROSA SUR E-19  URBANA  VIAS PUBLICAS
# ...                    ...                    ...     ...            ...
# 136284 1900-01-01 16:46:00        EL PARAISO E-19  URBANA  VIAS PUBLICAS
# 136285 1900-01-01 18:36:00          SANTA FE E-14  URBANA  VIAS PUBLICAS
# 136310 1900-01-01 22:00:00       LA FAVORITA E-14  URBANA  VIAS PUBLICAS
# 136311 1900-01-01 23:45:00  FONTANAR DEL RIO E-11  URBANA  VIAS PUBLICAS
# 136312 1900-01-01 15:24:00     SAN BERNARDINO E-7  URBANA  VIAS PUBLICAS
#
#         arma_empleada movil_agresor  ...       sexo  estado_civil  \
# 29        ARMA BLANCA         A PIE  ...  MASCULINO       SOLTERO
# 30        ARMA BLANCA         A PIE  ...  MASCULINO       SOLTERO
# 31        ARMA BLANCA         A PIE  ...  MASCULINO       SOLTERO
# 32      ARMA DE FUEGO         A PIE  ...  MASCULINO       SOLTERO
# 33      ARMA DE FUEGO         A PIE  ...   FEMENINO       SOLTERO
# ...               ...           ...  ...        ...           ...
# 136284    ARMA BLANCA         A PIE  ...  MASCULINO       SOLTERO
# 136285  ARMA DE FUEGO         A PIE  ...  MASCULINO       SOLTERO
# 136310    ARMA BLANCA         A PIE  ...  MASCULINO       SOLTERO
# 136311    ARMA BLANCA         A PIE  ...  MASCULINO   UNION LIBRE
# 136312    ARMA BLANCA         A PIE  ...  MASCULINO   UNION LIBRE
#
#        pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# 29               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 30               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 31                ECUADOR  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 32               COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 33               COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# ...                   ...                  ...           ...         ...
# 136284           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136285           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136310           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136311           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136312           COLOMBIA          DESEMPLEADO           NaN  SECUNDARIA
#
#        codigo_dane cantidad  year  hora_int
# 29      11001000.0      NaN  2010         0
# 30      11001000.0      NaN  2010         1
# 31      11001000.0      NaN  2010         2
# 32      11001000.0      NaN  2010         3
# 33      11001000.0      NaN  2010         3
# ...            ...      ...   ...       ...
# 136284  11001000.0      1.0  2019        16
# 136285  11001000.0      1.0  2019        18
# 136310  11001000.0      1.0  2019        22
# 136311  11001000.0      1.0  2019        23
# 136312  11001000.0      1.0  2019        15
#
# [12653 rows x 22 columns]

# %%
df_f.barrio.unique()
# Out:
# array(['SANTA CECILIA I E-11', 'VILLA GLORIA E-19', 'LA FAVORITA E-14',
#        ..., 'AVORIAZ E-1', 'LAS ORQUIDEAS E-1', 'FONTANAR DEL RIO E-11'],
#       dtype=object)

# %%
df_f['barrio'] = df_f['barrio'].map(lambda x: str(x)[:-4])
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_f.barrio.unique()
# Out:
# array(['SANTA CECILIA I ', 'VILLA GLORIA ', 'LA FAVORITA ', ...,
#        'AVORIAZ', 'LAS ORQUIDEAS', 'FONTANAR DEL RIO '], dtype=object)

# %%
df_f['barrio'] = df_f['barrio'].map(lambda x: str(x).strip())
# Out:
# /home/santiagotc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_f.barrio.unique().shape
# Out:
# (1635,)

# %%
coordenadas = pd.read_csv('coordenadas_barrios_bogota.csv')

# %%
coordenadas.rename(columns = {'name':'barrio'}, inplace = True)

# %%
cols = ['barrio']
df_f = df_f.join(coordenadas.set_index(cols), on=cols)
#total1['Hosp'].fillna(0, inplace=True)

# %%
df_f
# Out:
#                       fecha  departamento    municipio      dia  \
# 29      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 30      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 31      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 32      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 33      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# ...                     ...           ...          ...      ...
# 136284  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136285  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136310  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136311  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136312  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
#
#                       hora            barrio    zona clase_de_sitio  \
# 29     1900-01-01 00:10:00   SANTA CECILIA I  URBANA  VIAS PUBLICAS
# 30     1900-01-01 01:27:00      VILLA GLORIA  URBANA  VIAS PUBLICAS
# 31     1900-01-01 02:22:00       LA FAVORITA  URBANA  VIAS PUBLICAS
# 32     1900-01-01 03:17:00        QUIRIGUA I  URBANA  VIAS PUBLICAS
# 33     1900-01-01 03:56:00    SANTA ROSA SUR  URBANA  VIAS PUBLICAS
# ...                    ...               ...     ...            ...
# 136284 1900-01-01 16:46:00        EL PARAISO  URBANA  VIAS PUBLICAS
# 136285 1900-01-01 18:36:00          SANTA FE  URBANA  VIAS PUBLICAS
# 136310 1900-01-01 22:00:00       LA FAVORITA  URBANA  VIAS PUBLICAS
# 136311 1900-01-01 23:45:00  FONTANAR DEL RIO  URBANA  VIAS PUBLICAS
# 136312 1900-01-01 15:24:00    SAN BERNARDINO  URBANA  VIAS PUBLICAS
#
#         arma_empleada movil_agresor  ... pais_de_nacimiento  \
# 29        ARMA BLANCA         A PIE  ...           COLOMBIA
# 30        ARMA BLANCA         A PIE  ...           COLOMBIA
# 31        ARMA BLANCA         A PIE  ...            ECUADOR
# 32      ARMA DE FUEGO         A PIE  ...           COLOMBIA
# 33      ARMA DE FUEGO         A PIE  ...           COLOMBIA
# ...               ...           ...  ...                ...
# 136284    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136285  ARMA DE FUEGO         A PIE  ...           COLOMBIA
# 136310    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136311    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136312    ARMA BLANCA         A PIE  ...           COLOMBIA
#
#           clase_de_empleado   profesiones escolaridad codigo_dane cantidad  \
# 29      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 30      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 31      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 32               ESTUDIANTE  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 33            INDEPENDIENTE  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# ...                     ...           ...         ...         ...      ...
# 136284        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136285        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136310        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136311        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136312          DESEMPLEADO           NaN  SECUNDARIA  11001000.0      1.0
#
#         year hora_int       lat        lon
# 29      2010        0       NaN        NaN
# 30      2010        1  4.549735 -74.152364
# 31      2010        2  4.609963 -74.078646
# 32      2010        3  4.711938 -74.100686
# 33      2010        3       NaN        NaN
# ...      ...      ...       ...        ...
# 136284  2019       16  4.540863 -74.091920
# 136285  2019       18  4.615873 -74.077311
# 136310  2019       22  4.609963 -74.078646
# 136311  2019       23       NaN        NaN
# 136312  2019       15  4.593128 -74.084891
#
# [14344 rows x 24 columns]

# %%
df_f.isnull().sum()
# Out:
# fecha                    0
# departamento             0
# municipio                0
# dia                      0
# hora                     0
# barrio                   0
# zona                     0
# clase_de_sitio           0
# arma_empleada            0
# movil_agresor           18
# movil_victima           18
# edad                     4
# sexo                     0
# estado_civil             4
# pais_de_nacimiento      24
# clase_de_empleado        0
# profesiones           9709
# escolaridad              2
# codigo_dane              0
# cantidad              4635
# year                     0
# hora_int                 0
# lat                   6555
# lon                   6555
# dtype: int64

# %%
df_f_no_coord = df_f[df_f['lat'].isnull()]

# %%
df_f_coord = df_f[df_f['lat'].notnull()]

# %%
df_f.barrio.unique().shape
# Out:
# (1635,)

# %%
df_f_no_coord.barrio.unique().shape
# Out:
# (1144,)

# %%
df_f_coord.barrio.unique().shape
# Out:
# (491,)

# %%
df_f_coord_simplified = df_f_coord[]
# Out:
#   File "<ipython-input-46-1bc0922f9903>", line 1
#     df_f_coord_simplified = df_f_coord[]
#                                        ^
# SyntaxError: invalid syntax

# %%
TotalH1=df_f_coord.groupby(['barrio'])['hora_int'].count().reset_index(name='Total')

# %%
cols = ['barrio']
df_f_definitivo = TotalH1.join(coordenadas.set_index(cols), on=cols)

# %%
df_f_definitivo
# Out:
#                  barrio  Total       lat        lon
# 0        ACEVEDO TEJADA      1  4.630691 -74.081465
# 1          AGUAS CLARAS     10  4.557023 -74.069100
# 2                ALASKA      4  4.529911 -74.111248
# 3                ALCALA      5  4.603044 -74.126449
# 4             ALCAZARES      6  4.662511 -74.070415
# ..                  ...    ...       ...        ...
# 486  VILLAS EL DIAMANTE      9  4.550524 -74.153755
# 487            VILLEMAR      4  4.670606 -74.140076
# 488             VITELMA     14  4.575928 -74.077078
# 489       VOTO NACIONAL     75  4.603330 -74.083741
# 490        YOMASA NORTE     28  4.500939 -74.121643
#
# [548 rows x 4 columns]

# %%
import folium  #needed for interactive map
from folium.plugins import HeatMap

# %%
max_amount = float(df_f_definitivo['Total'].max())

folium_hmap = folium.Map(location=[4.728381, -74.046869],
                        zoom_start=13,
                        tiles='CartoDB positron')

hm_wide = HeatMap( list(zip(df_f_definitivo['lat'], df_f_definitivo['lon'], df_f_definitivo['Total'])),
                   min_opacity=0.2,
                   max_val=max_amount,
                   radius=20, blur=6, 
                   max_zoom=15, 
                 )

folium_hmap.add_child(hm_wide)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_f_definitivo
# Out:
#                  barrio  Total       lat        lon
# 0        ACEVEDO TEJADA      1  4.630691 -74.081465
# 1          AGUAS CLARAS     10  4.557023 -74.069100
# 2                ALASKA      4  4.529911 -74.111248
# 3                ALCALA      5  4.603044 -74.126449
# 4             ALCAZARES      6  4.662511 -74.070415
# ..                  ...    ...       ...        ...
# 486  VILLAS EL DIAMANTE      9  4.550524 -74.153755
# 487            VILLEMAR      4  4.670606 -74.140076
# 488             VITELMA     14  4.575928 -74.077078
# 489       VOTO NACIONAL     75  4.603330 -74.083741
# 490        YOMASA NORTE     28  4.500939 -74.121643
#
# [548 rows x 4 columns]

# %%
TotalH1
# Out:
#                  barrio  Total
# 0        ACEVEDO TEJADA      1
# 1          AGUAS CLARAS     10
# 2                ALASKA      4
# 3                ALCALA      5
# 4             ALCAZARES      6
# ..                  ...    ...
# 486  VILLAS EL DIAMANTE      9
# 487            VILLEMAR      4
# 488             VITELMA     14
# 489       VOTO NACIONAL     75
# 490        YOMASA NORTE     28
#
# [491 rows x 2 columns]

# %%
df_f_coord
# Out:
#                       fecha  departamento    municipio      dia  \
# 30      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 31      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 32      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 38      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# 39      2010-01-01 00:00:00  CUNDINAMARCA  BOGOTA D.C.  Viernes
# ...                     ...           ...          ...      ...
# 136284  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136284  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136285  2019-12-30 00:00:00  CUNDINAMARCA  BOGOTA D.C.    Lunes
# 136310  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
# 136312  2019-12-31 00:00:00  CUNDINAMARCA  BOGOTA D.C.   Martes
#
#                       hora          barrio    zona clase_de_sitio  \
# 30     1900-01-01 01:27:00    VILLA GLORIA  URBANA  VIAS PUBLICAS
# 31     1900-01-01 02:22:00     LA FAVORITA  URBANA  VIAS PUBLICAS
# 32     1900-01-01 03:17:00      QUIRIGUA I  URBANA  VIAS PUBLICAS
# 38     1900-01-01 08:10:00     LA VICTORIA  URBANA  VIAS PUBLICAS
# 39     1900-01-01 10:35:00          POTOSI  URBANA  VIAS PUBLICAS
# ...                    ...             ...     ...            ...
# 136284 1900-01-01 16:46:00      EL PARAISO  URBANA  VIAS PUBLICAS
# 136284 1900-01-01 16:46:00      EL PARAISO  URBANA  VIAS PUBLICAS
# 136285 1900-01-01 18:36:00        SANTA FE  URBANA  VIAS PUBLICAS
# 136310 1900-01-01 22:00:00     LA FAVORITA  URBANA  VIAS PUBLICAS
# 136312 1900-01-01 15:24:00  SAN BERNARDINO  URBANA  VIAS PUBLICAS
#
#         arma_empleada movil_agresor  ... pais_de_nacimiento  \
# 30        ARMA BLANCA         A PIE  ...           COLOMBIA
# 31        ARMA BLANCA         A PIE  ...            ECUADOR
# 32      ARMA DE FUEGO         A PIE  ...           COLOMBIA
# 38      ARMA DE FUEGO         A PIE  ...           COLOMBIA
# 39      ARMA DE FUEGO         A PIE  ...           COLOMBIA
# ...               ...           ...  ...                ...
# 136284    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136284    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136285  ARMA DE FUEGO         A PIE  ...           COLOMBIA
# 136310    ARMA BLANCA         A PIE  ...           COLOMBIA
# 136312    ARMA BLANCA         A PIE  ...           COLOMBIA
#
#           clase_de_empleado   profesiones escolaridad codigo_dane cantidad  \
# 30      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 31      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 32               ESTUDIANTE  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 38              DESEMPLEADO  NO REPORTADO  SECUNDARIA  11001000.0      NaN
# 39      EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA  11001000.0      NaN
# ...                     ...           ...         ...         ...      ...
# 136284        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136284        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136285        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136310        INDEPENDIENTE           NaN  SECUNDARIA  11001000.0      1.0
# 136312          DESEMPLEADO           NaN  SECUNDARIA  11001000.0      1.0
#
#         year hora_int       lat        lon
# 30      2010        1  4.549735 -74.152364
# 31      2010        2  4.609963 -74.078646
# 32      2010        3  4.711938 -74.100686
# 38      2010        8  4.551783 -74.092221
# 39      2010       10  4.569170 -74.170351
# ...      ...      ...       ...        ...
# 136284  2019       16  4.627185 -74.059534
# 136284  2019       16  4.540863 -74.091920
# 136285  2019       18  4.615873 -74.077311
# 136310  2019       22  4.609963 -74.078646
# 136312  2019       15  4.593128 -74.084891
#
# [7789 rows x 24 columns]

# %%
df_f_coord_KDE = df_f_coord[['lat', 'lon']]

# %%
df_f_coord_KDE
# Out:
#              lat        lon
# 30      4.549735 -74.152364
# 31      4.609963 -74.078646
# 32      4.711938 -74.100686
# 38      4.551783 -74.092221
# 39      4.569170 -74.170351
# ...          ...        ...
# 136284  4.627185 -74.059534
# 136284  4.540863 -74.091920
# 136285  4.615873 -74.077311
# 136310  4.609963 -74.078646
# 136312  4.593128 -74.084891
#
# [7789 rows x 2 columns]

# %%
df_f_coord_KDE = df_f_coord_KDE.to_numpy()

# %%
df_f_coord_KDE.shape
# Out:
# (7789, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_species_distributions
from sklearn.neighbors import KernelDensity

# %%
Xtrain = df_f_coord_KDE
ytrain = np.ones(7789)

ygrid = np.linspace(3.80, 4.82, num = 283)
xgrid = np.linspace(-74.38, -74.02, num = 100)


#X, Y = np.meshgrid(xgrid[::5], ygrid[::5][::-1])

X, Y = np.meshgrid(xgrid, ygrid)

xy = np.vstack([Y.ravel(), X.ravel()]).T

# %%
Xtrain[:,0].min()
# Out:
# 3.809720128555752

# %%
Xtrain[:,0].max()
# Out:
# 4.819483937375536

# %%
Xtrain[:,1].min()
# Out:
# -74.3732223241509

# %%
Xtrain[:,1].max()
# Out:
# -74.01937155645214

# %%
# construct a kernel density estimate of the distribution
print(" - computing KDE in spherical coordinates")
kde = KernelDensity(bandwidth=0.01, metric='haversine',
                    kernel='gaussian', algorithm='ball_tree')
kde.fit(Xtrain)
# Out:
#  - computing KDE in spherical coordinates
# KernelDensity(algorithm='ball_tree', atol=0, bandwidth=0.01, breadth_first=True,
#               kernel='gaussian', leaf_size=40, metric='haversine',
#               metric_params=None, rtol=0)

# %%
xy.shape
# Out:
# (28300, 2)

# %%
Z = kde.score_samples(xy)
#Z = Z.reshape(X.shape)

# %%
Z.shape
# Out:
# (28300,)

# %%
Z
# Out:
# array([-0.12357967, -0.01160242,  0.01827175, ..., -0.6233181 ,
#        -0.64214904, -0.66242962])

# %%
np.exp(Z)
# Out:
# array([0.88375123, 0.98846463, 1.01843969, ..., 0.53616244, 0.52616047,
#        0.51559711])

# %%
max_amount = float(df_f_definitivo['Total'].max())

folium_hmap = folium.Map(location=[4.728381, -74.046869],
                        zoom_start=13,
                        tiles='CartoDB positron')

hm_wide = HeatMap( list(zip(xy[:,0], xy[:,1], np.exp(Z))),
                   min_opacity=0.005,
                   max_val=max_amount,
                   radius=15, blur=6, 
                   max_zoom=15, 
                 )

folium_hmap.add_child(hm_wide)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
