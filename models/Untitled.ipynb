# %% [markdown]
# ## Proportions of crimes

# %% [markdown]
# Due to the amount of crimes that occurs per locality, it is impossible to have a model for each of these, so the procedure is to have a model for the entire city and then do a scalization based on the hisorical proportions. This process only works if we see that the proportions are kept during the years

# %%
import pandas as pd

# %%
data = pd.read_pickle('./Proporciones/del_sexuales_2016.pkl')

# %%
# Out:
#               localidad   year_  count       prop
# 7               SUMAPAZ  2016.0     43   1.177115
# 18             SANTA FE  2016.0     85   2.326855
# 20                 USME  2016.0    241   6.597317
# 26             FONTIBON  2016.0     97   2.655352
# 34       BARRIOS UNIDOS  2016.0    114   3.120723
# 44       CIUDAD BOLIVAR  2016.0    336   9.197920
# 56            CHAPINERO  2016.0    114   3.120723
# 92       ANTONIO NARIÑO  2016.0     53   1.450862
# 96           TUNJUELITO  2016.0    129   3.531344
# 100             KENNEDY  2016.0    319   8.732549
# 105            ENGATIVA  2016.0    274   7.500684
# 109         TEUSAQUILLO  2016.0    123   3.367096
# 124                SUBA  2016.0    375  10.265535
# 133          CANDELARIA  2016.0     25   0.684369
# 152                BOSA  2016.0    276   7.555434
# 164       PUENTE ARANDA  2016.0     92   2.518478
# 167             USAQUEN  2016.0    413  11.305776
# 171        LOS MARTIRES  2016.0     66   1.806734
# ...
