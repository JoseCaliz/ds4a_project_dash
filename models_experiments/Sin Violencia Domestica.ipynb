# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime
import os
from unidecode import unidecode
import joblib

# %%
driver = 'postgres'
username = 'ds4a'
password = 'ds4A-7eaM79'
host = 'ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com'
port = 5432
database = 'team_79'

connection_string = f'{driver}://{username}@{host}:{port}/{database}'
engine = create_engine(connection_string, encoding='utf-8')

# %%
# %load_ext sql

# %%
# %sql postgresql://ds4a:ds4A-7eaM79@ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com/team_79
# Out:
# 'Connected: ds4a@team_79'

# %%
credentials = "postgresql://ds4a:ds4A-7eaM79@ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com/team_79"

# %%
df_homicidios = pd.read_sql("""
                    SELECT barrio, edad, sexo, hora FROM homicidios
                    WHERE municipio = 'BOGOTÁ D.C.'
                    """,con=credentials)
matcher = pd.read_csv('matcher.csv', encoding='UTF8')
mapper = matcher.set_index('barrio_original').to_dict()['nom_match']
df_homicidios['mapid'] = df_homicidios.barrio.map(mapper)
df_homicidios.drop(columns = ['barrio'], inplace = True)
df_homicidios.rename(columns = {'mapid':'barrio'}, inplace = True)
df_homicidios.dropna(inplace = True)
df_homicidios = df_homicidios[df_homicidios['edad']<=100]
df_homicidios = df_homicidios[df_homicidios['edad']>9]
bins = pd.IntervalIndex.from_tuples([(10, 19), (20, 29), (30, 39),(40, 49),(50, 59),(60, 69),(70, 79),(80, 89),(90, 99)])
df_homicidios['edad'] = pd.cut(df_homicidios['edad'], bins)
df_homicidios.dropna(inplace = True)
df_homicidios['crimen'] = 0

# %%
df_homicidios
# Out:
#            edad       sexo  hora          barrio  crimen
# 1      (50, 59]  MASCULINO   1.0    VILLA GLORIA       0
# 2      (40, 49]  MASCULINO   2.0     LA FAVORITA       0
# 3      (10, 19]  MASCULINO   3.0      QUIRIGUA I       0
# 4      (20, 29]   FEMENINO   3.0      SANTA ROSA       0
# 5      (20, 29]  MASCULINO   3.0      SANTA ROSA       0
# ...         ...        ...   ...             ...     ...
# 12647  (50, 59]  MASCULINO  23.0       CHICO SUR       0
# 12648  (20, 29]  MASCULINO  16.0      EL PARAISO       0
# 12649  (20, 29]  MASCULINO  18.0        SANTA FE       0
# 12650  (20, 29]  MASCULINO  22.0     LA FAVORITA       0
# 12652  (20, 29]  MASCULINO  15.0  SAN BERNARDINO       0
#
# [10912 rows x 5 columns]

# %%
df_lesiones_personales = pd.read_sql("""
                    SELECT barrio, edad, sexo, hora FROM lesiones_personales
                    WHERE municipio = 'BOGOTÁ D.C.'
                    """,con=credentials)
matcher = pd.read_csv('matcher.csv', encoding='UTF8')
mapper = matcher.set_index('barrio_original').to_dict()['nom_match']
df_lesiones_personales['mapid'] = df_lesiones_personales.barrio.map(mapper)
df_lesiones_personales.drop(columns = ['barrio'], inplace = True)
df_lesiones_personales.rename(columns = {'mapid':'barrio'}, inplace = True)
df_lesiones_personales.dropna(inplace = True)
df_lesiones_personales = df_lesiones_personales[df_lesiones_personales['edad']<=100]
df_lesiones_personales = df_lesiones_personales[df_lesiones_personales['edad']>9]
bins = pd.IntervalIndex.from_tuples([(10, 19), (20, 29), (30, 39),(40, 49),(50, 59),(60, 69),(70, 79),(80, 89),(90, 99)])
df_lesiones_personales['edad'] = pd.cut(df_lesiones_personales['edad'], bins)
df_lesiones_personales.dropna(inplace = True)
df_lesiones_personales['crimen'] = 1

# %%
df_lesiones_personales
# Out:
#             edad       sexo  hora          barrio  crimen
# 9       (30, 39]  MASCULINO  19.0   SAN FRANCISCO       1
# 58      (60, 69]   FEMENINO   9.0       CHICO SUR       1
# 108     (30, 39]   FEMENINO  23.0         EL TUNO       1
# 118     (10, 19]  MASCULINO   2.0  SANTA TERESITA       1
# 130     (30, 39]   FEMENINO   5.0         EL TUNO       1
# ...          ...        ...   ...             ...     ...
# 186360  (10, 19]  MASCULINO  10.0          MONTES       1
# 186420  (20, 29]   FEMENINO  14.0        RICAURTE       1
# 186427  (20, 29]  MASCULINO  19.0       CHICO SUR       1
# 186430  (10, 19]  MASCULINO  20.0        RICAURTE       1
# 186442  (20, 29]  MASCULINO   9.0          EL POA       1
#
# [9512 rows x 5 columns]

# %%
X = df_homicidios.append(df_lesiones_personales)

# %%
df_hurto_personas = pd.read_sql("""
                    SELECT barrio, edad, sexo, hora FROM hurto_personas
                    WHERE municipio = 'BOGOTÁ D.C.'
                    """,con=credentials)
matcher = pd.read_csv('matcher.csv', encoding='UTF8')
mapper = matcher.set_index('barrio_original').to_dict()['nom_match']
df_hurto_personas['mapid'] = df_hurto_personas.barrio.map(mapper)
df_hurto_personas.drop(columns = ['barrio'], inplace = True)
df_hurto_personas.rename(columns = {'mapid':'barrio'}, inplace = True)
df_hurto_personas.dropna(inplace = True)
df_hurto_personas = df_hurto_personas[df_hurto_personas['edad']<=100]
df_hurto_personas = df_hurto_personas[df_hurto_personas['edad']>9]
bins = pd.IntervalIndex.from_tuples([(10, 19), (20, 29), (30, 39),(40, 49),(50, 59),(60, 69),(70, 79),(80, 89),(90, 99)])
df_hurto_personas['edad'] = pd.cut(df_hurto_personas['edad'], bins)
df_hurto_personas.dropna(inplace = True)
df_hurto_personas['crimen'] = 2

# %%
df_hurto_personas
# Out:
#             edad       sexo  hora                 barrio  crimen
# 1       (30, 39]   FEMENINO    19      CHAPINERO CENTRAL       2
# 2       (20, 29]   FEMENINO    19      CHAPINERO CENTRAL       2
# 3       (30, 39]  MASCULINO    19      CHAPINERO CENTRAL       2
# 5       (50, 59]  MASCULINO    19        CHAPINERO NORTE       2
# 6       (50, 59]   FEMENINO    19                EL REAL       2
# ...          ...        ...   ...                    ...     ...
# 485652  (20, 29]  MASCULINO     2               AURES II       2
# 485653  (30, 39]  MASCULINO     5            PALERMO SUR       2
# 485654  (50, 59]  MASCULINO     8  SANTA BARBARA CENTRAL       2
# 485655  (30, 39]  MASCULINO    10            LA CATEDRAL       2
# 485657  (20, 29]  MASCULINO    21              SAN DIEGO       2
#
# [426042 rows x 5 columns]

# %%
X = X.append(df_hurto_personas)

# %%
df_del_sexuales = pd.read_sql("""
                    SELECT barrio, edad, sexo, hora FROM del_sexuales
                    WHERE municipio = 'BOGOTÁ D.C.'
                    """,con=credentials)
matcher = pd.read_csv('matcher.csv', encoding='UTF8')
mapper = matcher.set_index('barrio_original').to_dict()['nom_match']
df_del_sexuales['mapid'] = df_del_sexuales.barrio.map(mapper)
df_del_sexuales.drop(columns = ['barrio'], inplace = True)
df_del_sexuales.rename(columns = {'mapid':'barrio'}, inplace = True)
df_del_sexuales.dropna(inplace = True)
df_del_sexuales = df_del_sexuales[df_del_sexuales['edad']<=100]
df_del_sexuales = df_del_sexuales[df_del_sexuales['edad']>9]
bins = pd.IntervalIndex.from_tuples([(10, 19), (20, 29), (30, 39),(40, 49),(50, 59),(60, 69),(70, 79),(80, 89),(90, 99)])
df_del_sexuales['edad'] = pd.cut(df_del_sexuales['edad'], bins)
df_del_sexuales.dropna(inplace = True)
df_del_sexuales['crimen'] = 3

# %%
df_del_sexuales
# Out:
#            edad       sexo  hora       barrio  crimen
# 0      (40, 49]   FEMENINO    19  BELLA SUIZA       3
# 1      (10, 19]   FEMENINO     0  BELLA SUIZA       3
# 2      (10, 19]   FEMENINO     0  BELLA SUIZA       3
# 3      (10, 19]   FEMENINO     0  BELLA SUIZA       3
# 4      (20, 29]   FEMENINO    12        OLAYA       3
# ...         ...        ...   ...          ...     ...
# 27804  (10, 19]   FEMENINO    18  BELLA SUIZA       3
# 27805  (20, 29]  MASCULINO     0  BELLA SUIZA       3
# 27806  (10, 19]   FEMENINO    10  BELLA SUIZA       3
# 27807  (10, 19]   FEMENINO    14  BELLA SUIZA       3
# 27808  (40, 49]  MASCULINO    19  LA ASUNCION       3
#
# [19049 rows x 5 columns]

# %%
X = X.append(df_del_sexuales)

# %%
X
# Out:
#            edad       sexo  hora        barrio  crimen
# 1      (50, 59]  MASCULINO   1.0  VILLA GLORIA       0
# 2      (40, 49]  MASCULINO   2.0   LA FAVORITA       0
# 3      (10, 19]  MASCULINO   3.0    QUIRIGUA I       0
# 4      (20, 29]   FEMENINO   3.0    SANTA ROSA       0
# 5      (20, 29]  MASCULINO   3.0    SANTA ROSA       0
# ...         ...        ...   ...           ...     ...
# 27804  (10, 19]   FEMENINO  18.0   BELLA SUIZA       3
# 27805  (20, 29]  MASCULINO   0.0   BELLA SUIZA       3
# 27806  (10, 19]   FEMENINO  10.0   BELLA SUIZA       3
# 27807  (10, 19]   FEMENINO  14.0   BELLA SUIZA       3
# 27808  (40, 49]  MASCULINO  19.0   LA ASUNCION       3
#
# [465515 rows x 5 columns]

# %% [markdown]
# Table is ready, now dummies

# %%
X_new = pd.get_dummies(X, columns = ['barrio', 'edad', 'sexo', 'hora'])

# %%
y = X_new['crimen']

# %%
X_new = X_new.drop(columns = ['crimen'])

# %% [markdown]
# # Training

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB, ComplementNB, CategoricalNB
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, confusion_matrix, auc, accuracy_score, f1_score

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=100)
trainidx, testidx = [(tr,te) for tr, te in sss.split(X_new , y)][0]

# %%
X_train=X_new.iloc[trainidx]
X_test=X_new.iloc[testidx]
y_train=y.iloc[trainidx]
y_test=y.iloc[testidx]

# %%
X_train.shape
# Out:
# (325860, 1004)

# %%
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

# %%
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)
    return roc_auc_score(y_test, y_pred, average=average)

# %% [markdown]
# ## Bernoulli Naive Bayes

# %%
confusion_matrix(y_test, y_pred)#BernoulliNB
# Out:
# array([[   193,     46,   3002,     33],
#        [    12,    530,   2189,    122],
#        [   235,    302, 124599,   2677],
#        [     5,     31,   1826,   3853]])

# %%
print(classification_report(y_test, y_pred))#BernolliNB
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.06      0.10      3274
#            1       0.58      0.19      0.28      2853
#            2       0.95      0.97      0.96    127813
#            3       0.58      0.67      0.62      5715
#
#     accuracy                           0.92    139655
#    macro avg       0.63      0.47      0.49    139655
# weighted avg       0.91      0.92      0.91    139655

# %%
titles_options = [("Normalized BernoulliNB confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=None,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
# Out:
# Normalized BernoulliNB confusion matrix
# [[5.89492975e-02 1.40500916e-02 9.16921197e-01 1.00794136e-02]
#  [4.20609884e-03 1.85769366e-01 7.67262531e-01 4.27620049e-02]
#  [1.83862361e-03 2.36282694e-03 9.74853888e-01 2.09446613e-02]
#  [8.74890639e-04 5.42432196e-03 3.19510061e-01 6.74190726e-01]]

# %%
multiclass_roc_auc_score(y_test, y_pred) # BernoulliNB
# Out:
# 0.6594311694701998

# %% [markdown]
# ## Complement Naive Bayes

# %%
confusion_matrix(y_test, y_pred)#ComplementNB
# Out:
# array([[   693,    274,   1849,    458],
#        [     5,   2288,    348,    212],
#        [  4025,   5196, 105653,  12939],
#        [   128,    130,    737,   4720]])

# %%
print(classification_report(y_test, y_pred))#ComplementNB
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.21      0.17      3274
#            1       0.29      0.80      0.43      2853
#            2       0.97      0.83      0.89    127813
#            3       0.26      0.83      0.39      5715
#
#     accuracy                           0.81    139655
#    macro avg       0.42      0.67      0.47    139655
# weighted avg       0.91      0.81      0.85    139655

# %%
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
titles_options = [("Normalized ComplementNB confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=None,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Normalized ComplementNB confusion matrix
# [[0.21 0.08 0.56 0.14]
#  [0.   0.8  0.12 0.07]
#  [0.03 0.04 0.83 0.1 ]
#  [0.02 0.02 0.13 0.83]]

# %%
multiclass_roc_auc_score(y_test, y_pred) # ComplementNB
# Out:
# 0.7806698010482395

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
confusion_matrix(y_test, y_pred)#MultinomialNB
# Out:
# array([[    83,     51,   3135,      5],
#        [     2,    531,   2293,     27],
#        [    68,    299, 126404,   1042],
#        [     3,     50,   2739,   2923]])

# %%
print(classification_report(y_test, y_pred))#MultinomialNB
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.03      0.05      3274
#            1       0.57      0.19      0.28      2853
#            2       0.94      0.99      0.96    127813
#            3       0.73      0.51      0.60      5715
#
#     accuracy                           0.93    139655
#    macro avg       0.69      0.43      0.47    139655
# weighted avg       0.91      0.93      0.91    139655

# %%
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
titles_options = [("Normalized ComplementNB confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=None,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Normalized ComplementNB confusion matrix
# [[2.54e-02 1.56e-02 9.58e-01 1.53e-03]
#  [7.01e-04 1.86e-01 8.04e-01 9.46e-03]
#  [5.32e-04 2.34e-03 9.89e-01 8.15e-03]
#  [5.25e-04 8.75e-03 4.79e-01 5.11e-01]]

# %%
multiclass_roc_auc_score(y_test, y_pred) # MultinomialNB
# Out:
# 0.6263458316007181

# %% [markdown]
# # Saving and using the model

# %%
import joblib

# %%
joblib.dump(clf, 'naive_bayes_4_crimes.joblib.pkl', compress=9)
# Out:
# ['naive_bayes_4_crimes.joblib.pkl']

# %%
keys_1 = list(X_train.columns)

# %%
values = list(np.zeros(1004))

# %%
data = dict(zip(keys_1,values))

# %%
### ESTA ES LA INFO QUE INTRODUCE LA PERSONA
query = ['BELLA SUIZA', '(90, 99]', 'FEMENINO', '12.0']

# %%
base = ['barrio_','edad_', 'sexo_', 'hora_']
keys = [i + j for i, j in zip(base, query)]

# %%
data = dict(zip(keys_1,values))
for key in keys:
    data[key] = 1.0
test = pd.DataFrame(data, index=[0])

# %%
clf = joblib.load('naive_bayes_4_crimes.joblib.pkl')
probabilities = clf.predict_proba(test)
print('Murder:',probabilities[0,0],' Personal lesion:', probabilities[0,1], ' Robery:', probabilities[0,2], 'Sexual:', probabilities[0,3])
# Out:
# Murder: 0.2139142811967637  Personal lesion: 0.23284345094424577  Robery: 0.04373395610226999 Sexual: 0.5095083117567214

# %%
keys_1
# Out:
# ['barrio_ABRAHAM LINCOLN',
#  'barrio_ACACIAS USAQUEN',
#  'barrio_ACEVEDO TEJADA',
#  'barrio_AEROPUERTO EL DORADO',
#  'barrio_AGUAS CLARAS',
#  'barrio_ALAMOS',
#  'barrio_ALASKA',
#  'barrio_ALCALA',
#  'barrio_ALCAZARES',
#  'barrio_ALCAZARES NORTE',
#  'barrio_ALFONSO LOPEZ',
#  'barrio_ALMIRANTE COLON',
#  'barrio_ALQUERIA',
#  'barrio_ALQUERIA LA FRAGUA',
#  'barrio_ALQUERIA LA FRAGUA II',
#  'barrio_ALQUERIA LA FRAGUA NORTE',
#  'barrio_ALTAMIRA',
#  'barrio_ALTOS DE CHOZICA',
#  'barrio_ALTOS DE SUBA',
#  'barrio_ALTOS DEL POBLADO',
#  'barrio_ALTOS DEL ZIPA',
#  'barrio_ALTOS DEL ZUQUE',
#  'barrio_ANDALUCIA II',
#  'barrio_ANDES NORTE',
#  'barrio_ANTIGUO COUNTRY',
#  'barrio_ANTONIA SANTOS',
#  'barrio_ANTONIO JOSE DE SUCRE',
#  'barrio_ARABIA',
#  'barrio_ARBOLEDA SANTA TERESITA',
#  'barrio_ARBOLEDA SUR',
#  'barrio_ARBORIZADORA ALTA',
#  'barrio_ARBORIZADORA ALTA I',
#  'barrio_ARBORIZADORA BAJA',
#  'barrio_AREA ARTILLERIA',
#  'barrio_ARGELIA II',
#  'barrio_ARMENIA',
#  'barrio_ARRAYANES I',
#  'barrio_ARRAYANES VI',
#  'barrio_ATAHUALPA',
#  'barrio_ATENAS',
#  'barrio_ATLANTA',
#  'barrio_AURES',
#  'barrio_AURES II',
#  'barrio_AUTOPISTA MEDELLIN',
#  'barrio_AUTOPISTA SUR',
#  'barrio_BANCO CENTRAL',
#  'barrio_BAQUERO',
#  'barrio_BARAJAS NORTE',
#  'barrio_BARCELONA',
#  'barrio_BARCELONA SUR',
#  'barrio_BARLOVENTO',
#  'barrio_BARRANCAS',
#  'barrio_BARRANCAS NORTE',
#  'barrio_BARRANCAS ORIENTAL',
#  'barrio_BARRANQUILLITA',
#  'barrio_BATALLON CALDAS',
#  'barrio_BATAN',
#  'barrio_BAVARIA',
#  'barrio_BELALCAZAR',
#  'barrio_BELEN',
#  'barrio_BELLA FLOR',
#  'barrio_BELLA FLOR SUR',
#  'barrio_BELLA SUIZA',
#  'barrio_BELLAVISTA',
#  'barrio_BELLAVISTA LUCERO ALTO',
#  'barrio_BELLAVISTA OCCIDENTAL',
#  'barrio_BELLAVISTA SUR',
#  'barrio_BELLO HORIZONTE',
#  'barrio_BENJAMIN HERRERA',
#  'barrio_BERLIN',
#  'barrio_BETANIA',
#  'barrio_BILBAO',
#  'barrio_BOCHICA',
#  'barrio_BOCHICA II',
#  'barrio_BOITA',
#  'barrio_BOLIVIA',
#  'barrio_BOLIVIA ORIENTAL',
#  'barrio_BOLONIA',
#  'barrio_BOLONIA I',
#  'barrio_BONANZA',
#  'barrio_BOSA',
#  'barrio_BOSA NOVA',
#  'barrio_BOSA NOVA EL PORVENIR',
#  'barrio_BOSQUE CALDERON',
#  'barrio_BOSQUE DE LOS ALPES',
#  'barrio_BOSQUE DE MODELIA',
#  'barrio_BOSQUE DE PINOS',
#  'barrio_BOSQUE DE PINOS I',
#  'barrio_BOSQUE DE PINOS III',
#  'barrio_BOSQUE IZQUIERDO',
#  'barrio_BOSQUE POPULAR',
#  'barrio_BOSQUES DE SAN JORGE',
#  'barrio_BOYACA',
#  'barrio_BRASIL',
#  'barrio_BRASILIA',
#  'barrio_BRAVO PAEZ',
#  'barrio_BRAZUELOS OCCIDENTAL',
#  'barrio_BRAZUELOS OCCIDENTAL RURAL',
#  'barrio_BRISAS ALDEA FONTIBON',
#  'barrio_BRISAS DEL LLANO',
#  'barrio_BRISAS DEL VOLADOR',
#  'barrio_BRITALIA',
#  'barrio_BUENAVISTA',
#  'barrio_BUENOS AIRES',
#  'barrio_CALANDAIMA',
#  'barrio_CALLEJON SANTA BARBARA',
#  'barrio_CALVO SUR',
#  'barrio_CAMELIA II',
#  'barrio_CAMPANELLA',
#  'barrio_CAMPIN',
#  'barrio_CAMPIN OCCIDENTAL',
#  'barrio_CAMPO EUCARISTICO',
#  'barrio_CAMPO HERMOSO',
#  'barrio_CAMPO VERDE',
#  'barrio_CANADA O GUIRA',
#  'barrio_CANAIMA',
#  'barrio_CANAVERALEJO',
#  'barrio_CANDELARIA LA NUEVA',
#  'barrio_CANODROMO',
#  'barrio_CANTAGALLO',
#  'barrio_CAOBOS SALAZAR',
#  'barrio_CAPELLANIA',
#  'barrio_CAPITOLIO',
#  'barrio_CARACAS',
#  'barrio_CARACOLI',
#  'barrio_CARMEN DEL SOL',
#  'barrio_CASA BLANCA SUBA I',
#  'barrio_CASA BLANCA SUR',
#  'barrio_CASA DE TEJA',
#  'barrio_CASABLANCA',
#  'barrio_CASABLANCA SUBA',
#  'barrio_CASABLANCA SUBA II',
#  'barrio_CASTILLA',
#  'barrio_CATALINA',
#  'barrio_CATALINA II',
#  'barrio_CATALUNA',
#  'barrio_CEDRITOS',
#  'barrio_CEDRITOS DEL SUR',
#  'barrio_CEDRO NARVAEZ',
#  'barrio_CEDRO SALAZAR',
#  'barrio_CEMENTERIO JARDINES APOGEO',
#  'barrio_CENTENARIO',
#  'barrio_CENTRAL DE MEZCLAS',
#  'barrio_CENTRO ADMINISTRATIVO',
#  'barrio_CENTRO FONTIBON',
#  'barrio_CENTRO INDUSTRIAL',
#  'barrio_CENTRO NARINO',
#  'barrio_CENTRO USME',
#  'barrio_CENTRO USME RURAL',
#  'barrio_CENTRO USME RURAL I',
#  'barrio_CENTRO USME RURAL II',
#  'barrio_CENTRO USME URBANO',
#  'barrio_CERRO COLORADO',
#  'barrio_CERROS DE ORIENTE',
#  'barrio_CHAPINERITO',
#  'barrio_CHAPINERO CENTRAL',
#  'barrio_CHAPINERO NORTE',
#  'barrio_CHAPINERO OCCIDENTAL',
#  'barrio_CHARALA',
#  'barrio_CHARCO RURAL',
#  'barrio_CHARCO URBANO',
#  'barrio_CHARLES DE GAULLE',
#  'barrio_CHICALA',
#  'barrio_CHICO NORTE',
#  'barrio_CHICO NORTE II SECTOR',
#  'barrio_CHICO NORTE III SECTOR',
#  'barrio_CHICO SUR',
#  'barrio_CHIGUAZA RURAL',
#  'barrio_CHIGUAZA URBANO',
#  'barrio_CHORRERAS',
#  'barrio_CHUCUA DE LA VACA I',
#  'barrio_CHUCUA DE LA VACA II',
#  'barrio_CHUNIZA',
#  'barrio_CIUDAD BACHUE',
#  'barrio_CIUDAD BACHUE I ETAPA',
#  'barrio_CIUDAD BERNA',
#  'barrio_CIUDAD BOLIVAR',
#  'barrio_CIUDAD BOLIVAR RURAL I',
#  'barrio_CIUDAD BOLIVAR RURAL III',
#  'barrio_CIUDAD DE CALI',
#  'barrio_CIUDAD HUNZA',
#  'barrio_CIUDAD JARDIN SUR',
#  'barrio_CIUDAD KENNEDY',
#  'barrio_CIUDAD KENNEDY CENTRAL',
#  'barrio_CIUDAD KENNEDY NORTE',
#  'barrio_CIUDAD KENNEDY OCCIDENTAL',
#  'barrio_CIUDAD KENNEDY ORIENTAL',
#  'barrio_CIUDAD KENNEDY SUR',
#  'barrio_CIUDAD LONDRES I',
#  'barrio_CIUDAD SALITRE NOR-ORIENTAL',
#  'barrio_CIUDAD SALITRE SUR-ORIENTAL',
#  'barrio_CIUDAD TECHO II',
#  'barrio_CIUDAD UNIVERSITARIA',
#  'barrio_CIUDADELA COLSUBSIDIO',
#  'barrio_CIUDADELA EL RECREO',
#  'barrio_CIUDADELA EL RECREO II',
#  'barrio_CLARET',
#  'barrio_CLASS',
#  'barrio_CLUB DE LOS LAGARTOS',
#  'barrio_COLMENA I LOS PINARES',
#  'barrio_COLOMBIA',
#  'barrio_COLON',
#  'barrio_COLSEGUROS',
#  'barrio_COMPARTIR',
#  'barrio_COMUNEROS',
#  'barrio_CONCEPCION',
#  'barrio_CONCEPCION NORTE',
#  'barrio_CONEJERA',
#  'barrio_CORABASTOS',
#  'barrio_CORDILLERA DEL SUR',
#  'barrio_CORDOBA',
#  'barrio_CORREDOR FERREO DEL SUR',
#  'barrio_COSTA AZUL',
#  'barrio_COUNTRY CLUB',
#  'barrio_CUNDINAMARCA',
#  'barrio_CURUBITAL',
#  'barrio_DANUBIO',
#  'barrio_DANUBIO II',
#  'barrio_DELMONTE',
#  'barrio_DESARROLLO BRAZUELOS I',
#  'barrio_DIANA TURBAY',
#  'barrio_DINDALITO',
#  'barrio_DOCE DE OCTUBRE',
#  'barrio_DONA LILIANA',
#  'barrio_DUITAMA',
#  'barrio_EDUARDO FREY',
#  'barrio_EDUARDO SANTOS',
#  'barrio_EGIPTO',
#  'barrio_EL BAGAZAL',
#  'barrio_EL BOSQUE',
#  'barrio_EL BOSQUE CENTRAL',
#  'barrio_EL BOSQUE CENTRAL I',
#  'barrio_EL BOSQUE SUR ORIENTAL RURAL I',
#  'barrio_EL BOSQUE SUR ORIENTAL RURAL II',
#  'barrio_EL BOSQUE SUR ORIENTAL RURAL III',
#  'barrio_EL CARMELO',
#  'barrio_EL CARMEN',
#  'barrio_EL CARMEN FONTIBON',
#  'barrio_EL CEDRO',
#  'barrio_EL CEREZO',
#  'barrio_EL CHANCO I',
#  'barrio_EL CHANCO II',
#  'barrio_EL CHANCO RURAL III',
#  'barrio_EL CHARCO',
#  'barrio_EL CHICO',
#  'barrio_EL CONTADOR',
#  'barrio_EL CORTIJO',
#  'barrio_EL CORZO',
#  'barrio_EL CURUBO',
#  'barrio_EL DANUBIO AZUL',
#  'barrio_EL DORADO',
#  'barrio_EL DORADO INDUSTRIAL',
#  'barrio_EL EJIDO',
#  'barrio_EL ENCANTO',
#  'barrio_EL ENSUENO',
#  'barrio_EL GACO',
#  'barrio_EL GUAVIO',
#  'barrio_EL HATO',
#  'barrio_EL ISTMO',
#  'barrio_EL JARDIN',
#  'barrio_EL JAZMIN',
#  'barrio_EL LAUREL',
#  'barrio_EL LISTON',
#  'barrio_EL MADRIGAL',
#  'barrio_EL MINUTO DE DIOS',
#  'barrio_EL MINUTO DE MARIA',
#  'barrio_EL MIRADOR',
#  'barrio_EL MIRADOR DE LA ESTANCIA',
#  'barrio_EL MIRADOR II',
#  'barrio_EL MOCHUELO',
#  'barrio_EL MOCHUELO II NORTE',
#  'barrio_EL MOCHUELO ORIENTAL',
#  'barrio_EL MOCHUELO URBANO',
#  'barrio_EL MUELLE',
#  'barrio_EL NEVADO',
#  'barrio_EL NOGAL',
#  'barrio_EL NUEVO PORTAL',
#  'barrio_EL NUEVO PORTAL II',
#  'barrio_EL NUEVO PORTAL II RURAL',
#  'barrio_EL PANTANO',
#  'barrio_EL PARAISO',
#  'barrio_EL PEDREGAL',
#  'barrio_EL PEDREGAL II',
#  'barrio_EL PENON DEL CORTIJO',
#  'barrio_EL PINAR',
#  'barrio_EL PINO',
#  'barrio_EL PLAN',
#  'barrio_EL PLAYON',
#  'barrio_EL POA',
#  'barrio_EL PORTAL DEL BRASIL',
#  'barrio_EL PORTAL DEL DIVINO',
#  'barrio_EL PORTAL URBANO',
#  'barrio_EL PORVENIR DE LOS SOCHES',
#  'barrio_EL PROGRESO',
#  'barrio_EL PROGRESO USME',
#  'barrio_EL REAL',
#  'barrio_EL RECUERDO',
#  'barrio_EL REDIL',
#  'barrio_EL REFUGIO',
#  'barrio_EL REFUGIO I',
#  'barrio_EL REFUGIO II',
#  'barrio_EL REMANSO',
#  'barrio_EL REMANSO I',
#  'barrio_EL RETIRO',
#  'barrio_EL RINCON',
#  'barrio_EL RINCON NORTE',
#  'barrio_EL ROCIO',
#  'barrio_EL ROCIO NORTE',
#  'barrio_EL ROSARIO',
#  'barrio_EL RUBI',
#  'barrio_EL SALITRE',
#  'barrio_EL SALTEADOR',
#  'barrio_EL SATELITE',
#  'barrio_EL TABACO',
#  'barrio_EL TESORO',
#  'barrio_EL TINTAL',
#  'barrio_EL TINTAL CENTRAL',
#  'barrio_EL TINTAL II',
#  'barrio_EL TOBERIN',
#  'barrio_EL TRIANGULO',
#  'barrio_EL TUNO',
#  'barrio_EL UVAL',
#  'barrio_EL UVAL RURAL',
#  'barrio_EL VERGEL',
#  'barrio_EL VERGEL ORIENTAL',
#  'barrio_EL VERVENAL',
#  'barrio_EL VIRREY',
#  'barrio_EMAUS',
#  'barrio_ENGATIVA EL DORADO',
#  'barrio_ENGATIVA ZONA URBANA',
#  'barrio_ENTRERIOS',
#  'barrio_ESCOCIA',
#  'barrio_ESCUELA DE CABALLERIA I',
#  'barrio_ESCUELA DE CABALLERIA II',
#  'barrio_ESCUELA DE CARABINEROS',
#  'barrio_ESCUELA DE INFANTERIA',
#  'barrio_ESCUELA GENERAL SANTANDER',
#  'barrio_ESCUELA MILITAR',
#  'barrio_ESPARTILLAL',
#  'barrio_ESPINO I',
#  'barrio_ESTACION CENTRAL',
#  'barrio_ESTORIL',
#  'barrio_ESTRELLA',
#  'barrio_ESTRELLA DEL NORTE',
#  'barrio_FATIMA',
#  'barrio_FERROCAJA FONTIBON',
#  'barrio_FISCALA ALTA',
#  'barrio_FLORENCIA',
#  'barrio_FLORIDA',
#  'barrio_FLORIDA BLANCA',
#  'barrio_FRANCO',
#  'barrio_GALAN',
#  'barrio_GALAN RURAL',
#  'barrio_GALERIAS',
#  'barrio_GALICIA',
#  'barrio_GARCES NAVAS',
#  'barrio_GIBRALTAR SUR',
#  'barrio_GILMAR',
#  'barrio_GINEBRA',
#  'barrio_GINEBRA II',
#  'barrio_GIRARDOT',
#  'barrio_GORGONZOLA',
#  'barrio_GRAN AMERICA',
#  'barrio_GRAN BRITALIA',
#  'barrio_GRAN BRITALIA I',
#  'barrio_GRAN COLOMBIANO',
#  'barrio_GRAN GRANADA',
#  'barrio_GRAN YOMASA',
#  'barrio_GRANADA',
#  'barrio_GRANADA NORTE',
#  'barrio_GRANADA SUR',
#  'barrio_GRANJAS DE TECHO',
#  'barrio_GRANJAS SAN PABLO',
#  'barrio_GUADALUPE',
#  'barrio_GUADUAL FONTIBON',
#  'barrio_GUALOCHE',
#  'barrio_GUAYMARAL',
#  'barrio_GUIPARMA',
#  'barrio_GUSTAVO RESTREPO',
#  'barrio_HIPOTECHO OCCIDENTAL',
#  'barrio_HORIZONTES NORTE',
#  'barrio_HOSPITAL SAN CARLOS',
#  'barrio_HOYA SAN CRISTOBAL',
#  'barrio_HOYA TEUSACA',
#  'barrio_IBERIA',
#  'barrio_INDUSTRIAL CENTENARIO',
#  'barrio_INGEMAR',
#  'barrio_INGEMAR ORIENTAL I',
#  'barrio_INGLES',
#  'barrio_INTERINDUSTRIAL',
#  'barrio_IRAGUA',
#  'barrio_ISLA DEL SOL',
#  'barrio_ISLANDIA',
#  'barrio_ISMAEL PERDOMO',
#  'barrio_JACQUELINE',
#  'barrio_JARDIN BOTANICO',
#  'barrio_JERUSALEN',
#  'barrio_JIMENEZ DE QUESADA',
#  'barrio_JIMENEZ DE QUESADA II SECTOR',
#  'barrio_JORGE ELIECER GAITAN',
#  'barrio_JORGE GAITAN CORTES',
#  'barrio_JORGE URIBE BOTERO',
#  'barrio_JOSE ANTONIO GALAN',
#  'barrio_JOSE JOAQUIN VARGAS',
#  'barrio_JOSE MARIA CARBONEL',
#  'barrio_JUAN JOSE RONDON',
#  'barrio_JUAN PABLO II',
#  'barrio_JUAN REY SUR',
#  'barrio_JUAN XXIII',
#  'barrio_JULIO FLOREZ',
#  'barrio_KASANDRA',
#  'barrio_LA ALAMEDA',
#  'barrio_LA ANDREA',
#  'barrio_LA ARBOLEDA RURAL',
#  'barrio_LA ASUNCION',
#  'barrio_LA AURORA',
#  'barrio_LA BELLEZA',
#  'barrio_LA CABANA',
#  'barrio_LA CABRERA',
#  'barrio_LA CALLEJA',
#  'barrio_LA CAMELIA',
#  'barrio_LA CAMPINA',
#  'barrio_LA CANDELARIA',
#  'barrio_LA CAPUCHINA',
#  'barrio_LA CAROLINA',
#  'barrio_LA CAROLINA DE SUBA',
#  'barrio_LA CASTELLANA',
#  'barrio_LA CATEDRAL',
#  'barrio_LA CECILIA',
#  'barrio_LA CHUCUA',
#  'barrio_LA CITA',
#  'barrio_LA COMUNA',
#  'barrio_LA CONCORDIA',
#  'barrio_LA CORUNA',
#  'barrio_LA ESMERALDA',
#  'barrio_LA ESPERANZA',
#  'barrio_LA ESPERANZA NORTE',
#  'barrio_LA ESPERANZA SUR',
#  'barrio_LA ESPERANZA SUR I',
#  'barrio_LA ESTACION BOSA',
#  'barrio_LA ESTANCIA',
#  'barrio_LA ESTANZUELA',
#  'barrio_LA ESTRADA',
#  'barrio_LA ESTRADITA',
#  'barrio_LA ESTRELLITA',
#  'barrio_LA ESTRELLITA I',
#  'barrio_LA ESTRELLITA III',
#  'barrio_LA FAENA',
#  'barrio_LA FAVORITA',
#  'barrio_LA FISCALA',
#  'barrio_LA FISCALA NORTE',
#  'barrio_LA FLORIDA OCCIDENTAL',
#  'barrio_LA FRAGUA',
#  'barrio_LA FRAGUITA',
#  'barrio_LA GAITANA',
#  'barrio_LA GAITANA ORIENTAL',
#  'barrio_LA GIRALDA',
#  'barrio_LA GLORIA OCCIDENTAL',
#  'barrio_LA GLORIA ORIENTAL',
#  'barrio_LA GRANJA',
#  'barrio_LA GRANJA NORTE',
#  'barrio_LA HORTUA',
#  'barrio_LA HUERTA',
#  'barrio_LA INDEPENDENCIA',
#  'barrio_LA LAGUNA FONTIBON',
#  'barrio_LA LIBERIA',
#  'barrio_LA LIBERTAD',
#  'barrio_LA LOMITA',
#  'barrio_LA MACARENA',
#  'barrio_LA MAGDALENA',
#  'barrio_LA MARIA',
#  'barrio_LA MARICHUELA',
#  'barrio_LA MERCED',
#  'barrio_LA MERCED NORTE',
#  'barrio_LA ORQUIDEA DE USME',
#  'barrio_LA PAMPA',
#  'barrio_LA PATRIA',
#  'barrio_LA PAZ',
#  'barrio_LA PAZ BOSA',
#  'barrio_LA PENA',
#  'barrio_LA PEPITA',
#  'barrio_LA PERSEVERANCIA',
#  'barrio_LA PERSEVERANCIA I',
#  'barrio_LA PICOTA',
#  'barrio_LA PICOTA ORIENTAL',
#  'barrio_LA PRADERA',
#  'barrio_LA PRADERA NORTE',
#  'barrio_LA PRIMAVERA I',
#  'barrio_LA REFORMA',
#  'barrio_LA REGADERA',
#  'barrio_LA REQUILINA',
#  'barrio_LA REQUILINA RURAL',
#  'barrio_LA RESURRECCION',
#  'barrio_LA RESURRECCION I',
#  'barrio_LA RIVIERA',
#  'barrio_LA SABANA',
#  'barrio_LA SALLE',
#  'barrio_LA SERENA',
#  'barrio_LA SOLEDAD',
#  'barrio_LA SOLEDAD NORTE',
#  'barrio_LA TORRE',
#  'barrio_LA TRINIDAD',
#  'barrio_LA UNION',
#  'barrio_LA UNION URBANO',
#  'barrio_LA URIBE',
#  'barrio_LA VALVANERA',
#  'barrio_LA VEGA SAN BERNARDINO',
#  'barrio_LA VICTORIA',
#  'barrio_LAGO DE SUBA',
#  'barrio_LAGO GAITAN',
#  'barrio_LAGUNITAS',
#  'barrio_LAS ACACIAS',
#  'barrio_LAS AGUAS',
#  'barrio_LAS AMERICAS',
#  'barrio_LAS AURAS',
#  'barrio_LAS BRISAS',
#  'barrio_LAS CRUCES',
#  'barrio_LAS DELICIAS',
#  'barrio_LAS DELICIAS DEL CARMEN II SECTOR',
#  'barrio_LAS DOS AVENIDAS',
#  'barrio_LAS FERIAS',
#  'barrio_LAS FERIAS OCCIDENTAL',
#  'barrio_LAS FLORES',
#  'barrio_LAS GAVIOTAS',
#  'barrio_LAS GUACAMAYAS III',
#  'barrio_LAS LOMAS',
#  'barrio_LAS MANAS',
#  'barrio_LAS MARGARITAS',
#  'barrio_LAS MERCEDES',
#  'barrio_LAS NAVETAS',
#  'barrio_LAS NIEVES',
#  'barrio_LAS ORQUIDEAS',
#  'barrio_LAS PALMAS',
#  'barrio_LAS VEGAS',
#  'barrio_LAS VILLAS',
#  'barrio_LAS VIOLETAS',
#  'barrio_LIBERTADOR',
#  'barrio_LILIANA',
#  'barrio_LISBOA',
#  'barrio_LLANO GRANDE',
#  'barrio_LOMBARDIA',
#  'barrio_LOS ALAMOS',
#  'barrio_LOS ALMENDROS',
#  'barrio_LOS ALPES',
#  'barrio_LOS ALPES SUR',
#  'barrio_LOS ANDES',
#  'barrio_LOS ANGELES',
#  'barrio_LOS ARRAYANES',
#  'barrio_LOS ARRAYANES II',
#  'barrio_LOS CEDROS',
#  'barrio_LOS CEDROS ORIENTAL',
#  'barrio_LOS CEREZOS',
#  'barrio_LOS EJIDOS',
#  'barrio_LOS LACHES',
#  'barrio_LOS LAURELES',
#  'barrio_LOS LAURELES II',
#  'barrio_LOS LAURELES SUR ORIENTAL I',
#  'barrio_LOS LIBERTADORES',
#  'barrio_LOS MOLINOS',
#  'barrio_LOS NARANJOS',
#  'barrio_LOS OLIVARES',
#  'barrio_LOS RIOS',
#  'barrio_LOS ROSALES',
#  'barrio_LOS SAUCES',
#  'barrio_LOS SOCHES',
#  'barrio_LOS TRES REYES',
#  'barrio_LOS TRES REYES I',
#  'barrio_LOURDES',
#  'barrio_LUCERO ALTO',
#  'barrio_LUCERO DEL SUR',
#  'barrio_LUIS CARLOS GALAN',
#  'barrio_LUSITANIA',
#  'barrio_MADELENA',
#  'barrio_MANDALAY',
#  'barrio_MARANDU',
#  'barrio_MARCO FIDEL SUAREZ',
#  'barrio_MARCO FIDEL SUAREZ I',
#  'barrio_MARIA CANO',
#  'barrio_MARIA CRISTINA',
#  'barrio_MARIA PAZ',
#  'barrio_MARLY',
#  'barrio_MARRUECOS',
#  'barrio_MARSELLA',
#  'barrio_MAZUREN',
#  'barrio_MEISSEN',
#  'barrio_METROPOLIS',
#  'barrio_MEXICO',
#  'barrio_MILLAN',
#  'barrio_MIRADOR DEL NORTE',
#  'barrio_MIRANDELA',
#  'barrio_MODELIA',
#  'barrio_MODELIA OCCIDENTAL',
#  'barrio_MODELO SUR',
#  'barrio_MOLINOS DE ORIENTE',
#  'barrio_MOLINOS DEL SUR',
#  'barrio_MOLINOS NORTE',
#  'barrio_MONACO',
#  'barrio_MONTE CARLO',
#  'barrio_MONTEBELLO',
#  'barrio_MONTEBLANCO',
#  'barrio_MONTES',
#  'barrio_MONTEVIDEO',
#  'barrio_MORALBA',
#  'barrio_MORAVIA',
#  'barrio_MUEQUETA',
#  'barrio_MURILLO TORO',
#  'barrio_MUZU',
#  'barrio_NACIONES UNIDAS',
#  'barrio_NARINO SUR',
#  'barrio_NICOLAS DE FEDERMAN',
#  'barrio_NIZA NORTE',
#  'barrio_NIZA SUBA',
#  'barrio_NIZA SUR',
#  'barrio_NORMANDIA',
#  'barrio_NORMANDIA OCCIDENTAL',
#  'barrio_NUESTRA SENORA DEL ROSARIO',
#  'barrio_NUEVA DELHI',
#  'barrio_NUEVA ESPERANZA',
#  'barrio_NUEVA GLORIA',
#  'barrio_NUEVA GRANADA',
#  'barrio_NUEVA GRANADA BOSA',
#  'barrio_NUEVA TIBABUYES',
#  'barrio_NUEVA YORK',
#  'barrio_NUEVA ZELANDIA',
#  'barrio_NUEVO MUZU',
#  'barrio_NUEVO SAN ANDRES',
#  'barrio_NUEVO TECHO',
#  'barrio_OLARTE',
#  'barrio_OLAYA',
#  'barrio_ONCE DE NOVIEMBRE',
#  'barrio_ORTEZAL',
#  'barrio_OSORIO II',
#  'barrio_OSPINA PEREZ',
#  'barrio_PABLO VI NORTE',
#  'barrio_PALERMO',
#  'barrio_PALERMO SUR',
#  'barrio_PALO BLANCO',
#  'barrio_PALOQUEMAO',
#  'barrio_PARAMO',
#  'barrio_PARAMO I',
#  'barrio_PARAMO II',
#  'barrio_PARAMO IV',
#  'barrio_PARAMO URBANO',
#  'barrio_PARCELA EL PORVENIR',
#  'barrio_PARDO RUBIO',
#  'barrio_PARDO RUBIO  I',
#  'barrio_PARIS',
#  'barrio_PARIS GAITAN',
#  'barrio_PARQUE DISTRITAL SALITRE',
#  'barrio_PARQUE EL TUNAL',
#  'barrio_PARQUE NACIONAL',
#  'barrio_PARQUE NACIONAL ORIENTAL',
#  'barrio_PARQUE NACIONAL URBANO',
#  'barrio_PARQUE POPULAR SALITRE',
#  'barrio_PASADENA',
#  'barrio_PASO ANCHO',
#  'barrio_PASQUILLA',
#  'barrio_PASQUILLA URBANA',
#  'barrio_PASTRANA',
#  'barrio_PATIO BONITO',
#  'barrio_PATIO BONITO II',
#  'barrio_PATIO BONITO III',
#  'barrio_PAULO VI',
#  'barrio_PENALISA',
#  'barrio_PENSILVANIA',
#  'barrio_PERDOMO ALTO',
#  'barrio_PINOS DE LOMBARDIA',
#  'barrio_PIO XII',
#  'barrio_POLICARPA',
#  'barrio_POLO CLUB',
#  'barrio_POPULAR MODELO',
#  'barrio_PORCIUNCULA',
#  'barrio_PORTAL RURAL II',
#  'barrio_PORTALES DEL NORTE',
#  'barrio_PORVENIR',
#  'barrio_POTOSI',
#  'barrio_POTRERILLO',
#  'barrio_PRADO PINZON',
#  'barrio_PRADO VERANIEGO',
#  'barrio_PRADO VERANIEGO NORTE',
#  'barrio_PRADO VERANIEGO SUR',
#  'barrio_PRIMAVERA',
#  'barrio_PRIMAVERA II',
#  'barrio_PRIMAVERA OCCIDENTAL',
#  'barrio_PRIMERO DE MAYO',
#  'barrio_PROVIVIENDA',
#  'barrio_PROVIVIENDA NORTE',
#  'barrio_PROVIVIENDA OCCIDENTAL',
#  'barrio_PROVIVIENDA ORIENTAL',
#  'barrio_PUEBLO VIEJO',
#  'barrio_PUENTE ARANDA',
#  'barrio_PUENTE COLORADO',
#  'barrio_PUENTE GRANDE',
#  'barrio_PUENTE LARGO',
#  'barrio_PUERTA AL LLANO DE USME',
#  'barrio_PUERTA AL LLANO RURAL',
#  'barrio_PUERTA DE TEJA',
#  'barrio_PUERTA DEL SOL',
#  'barrio_PUERTO RICO',
#  'barrio_QUESADA',
#  'barrio_QUIBA',
#  'barrio_QUIBA RURAL',
#  'barrio_QUIBA URBANO',
#  'barrio_QUINDIO',
#  'barrio_QUINTA CAMACHO',
#  'barrio_QUINTA MUTIS',
#  'barrio_QUINTA PAREDES',
#  'barrio_QUINTA RAMOS',
#  'barrio_QUINTAS DEL SUR',
#  'barrio_QUIRIGUA I',
#  'barrio_QUIRIGUA II',
#  'barrio_QUIRIGUA ORIENTAL',
#  'barrio_QUIROGA',
#  'barrio_QUIROGA I',
#  'barrio_QUIROGA SUR',
#  'barrio_RAFAEL ESCAMILLA',
#  'barrio_RAFAEL NUNEZ',
#  'barrio_RAFAEL URIBE',
#  'barrio_RAMAJAL',
#  'barrio_RAMIREZ',
#  'barrio_REMANSO',
#  'barrio_REMANSO SUR',
#  'barrio_RENANIA URAPANES',
#  'barrio_RESTREPO',
#  'barrio_RESTREPO OCCIDENTAL',
#  'barrio_RICAURTE',
#  'barrio_RINCON ALTAMAR',
#  'barrio_RINCON DE GALICIA',
#  'barrio_RINCON DE LA VALVANERA',
#  'barrio_RINCON DE SANTA INES',
#  'barrio_RINCON DE SUBA',
#  'barrio_RINCON DEL CHICO',
#  'barrio_RIONEGRO',
#  'barrio_ROMA',
#  'barrio_RONDA',
#  'barrio_SABANA DE TIBABUYES',
#  'barrio_SABANA DE TIBABUYES NORTE',
#  'barrio_SABANA DEL DORADO',
#  'barrio_SABANA GRANDE',
#  'barrio_SAGRADO CORAZON',
#  'barrio_SALAZAR GOMEZ',
#  'barrio_SALITRE OCCIDENTAL',
#  'barrio_SALITRE SUBA',
#  'barrio_SAMORE',
#  'barrio_SAMPER',
#  'barrio_SAMPER MENDOZA',
#  'barrio_SAN AGUSTIN',
#  'barrio_SAN ANTONIO',
#  'barrio_SAN ANTONIO DEL MIRADOR',
#  'barrio_SAN ANTONIO ENGATIVA',
#  'barrio_SAN ANTONIO NOROCCIDENTAL',
#  'barrio_SAN ANTONIO NORTE',
#  'barrio_SAN BENITO',
#  'barrio_SAN BERNARDINO',
#  'barrio_SAN BERNARDINO I',
#  'barrio_SAN BERNARDINO II',
#  'barrio_SAN BERNARDINO POTRERITOS',
#  'barrio_SAN BERNARDINO XVIII',
#  'barrio_SAN BLAS',
#  'barrio_SAN BLAS II',
#  'barrio_SAN CARLOS',
#  'barrio_SAN CARLOS DE SUBA',
#  'barrio_SAN CAYETANO',
#  'barrio_SAN CRISTOBAL NORTE',
#  'barrio_SAN CRISTOBAL SUR',
#  'barrio_SAN DIEGO',
#  'barrio_SAN DIEGO-BOSA',
#  'barrio_SAN EUSEBIO',
#  'barrio_SAN FELIPE',
#  'barrio_SAN FERNANDO',
#  'barrio_SAN FERNANDO OCCIDENTAL',
#  'barrio_SAN FRANCISCO',
#  'barrio_SAN FRANCISCO RURAL',
#  'barrio_SAN GABRIEL',
#  'barrio_SAN GABRIEL NORTE',
#  'barrio_SAN GABRIEL NORTE II',
#  'barrio_SAN IGNACIO',
#  'barrio_SAN ISIDRO',
#  'barrio_SAN ISIDRO RURAL II',
#  'barrio_SAN JAVIER',
#  'barrio_SAN JOAQUIN',
#  'barrio_SAN JORGE SUR',
#  'barrio_SAN JOSE',
#  'barrio_SAN JOSE DE BAVARIA',
#  'barrio_SAN JOSE DE FONTIBON',
#  'barrio_SAN JOSE DEL PRADO',
#  'barrio_SAN JOSE SUR',
#  'barrio_SAN JOSE SUR ORIENTAL',
#  'barrio_SAN JOSE V SECTOR',
#  'barrio_SAN JUAN',
#  'barrio_SAN JUAN BAUTISTA',
#  'barrio_SAN JUAN URBANO',
#  'barrio_SAN LUIS',
#  'barrio_SAN LUIS ALTOS DEL CABO RURAL',
#  'barrio_SAN LUIS ALTOS DEL CABO RURAL II',
#  'barrio_SAN MARTIN',
#  'barrio_SAN MARTIN SUR',
#  'barrio_SAN MIGUEL',
#  'barrio_SAN PABLO BOSA',
#  'barrio_SAN PABLO JERICO',
#  'barrio_SAN PATRICIO',
#  'barrio_SAN PEDRO',
#  'barrio_SAN PEDRO DE LOS ROBLES',
#  'barrio_SAN PEDRO SUR',
#  'barrio_SAN RAFAEL',
#  'barrio_SAN RAFAEL INDUSTRIAL',
#  'barrio_SAN RAFAEL USME',
#  'barrio_SAN VICENTE',
#  'barrio_SAN VICENTE FERRER',
#  'barrio_SAN VICTORINO',
#  'barrio_SANTA ANA',
#  'barrio_SANTA ANA OCCIDENTAL',
#  'barrio_SANTA ANA SUR',
#  'barrio_SANTA BARBARA',
#  'barrio_SANTA BARBARA CENTRAL',
#  'barrio_SANTA BARBARA ORIENTAL',
#  'barrio_SANTA BIBIANA',
#  'barrio_SANTA CATALINA',
#  'barrio_SANTA CECILIA',
#  'barrio_SANTA CECILIA DE SUBA I',
#  'barrio_SANTA CECILIA PUENTE NORTE',
#  'barrio_SANTA FE',
#  'barrio_SANTA FE BOSA',
#  'barrio_SANTA HELENA',
#  'barrio_SANTA HELENITA',
#  'barrio_SANTA INES',
#  'barrio_SANTA INES SUR',
#  'barrio_SANTA INES SUR II',
#  'barrio_SANTA ISABEL',
#  'barrio_SANTA ISABEL SUR',
#  'barrio_SANTA LIBRADA',
#  'barrio_SANTA LIBRADA NORTE',
#  'barrio_SANTA LUCIA',
#  'barrio_SANTA MARIA',
#  'barrio_SANTA MATILDE',
#  'barrio_SANTA MONICA',
#  'barrio_SANTA RITA DE SUBA',
#  'barrio_SANTA RITA SUR ORIENTAL',
#  'barrio_SANTA ROSA',
#  'barrio_SANTA ROSA ALTA',
#  'barrio_SANTA ROSA BAJA',
#  'barrio_SANTA SOFIA',
#  'barrio_SANTA TERESA',
#  'barrio_SANTA TERESA DE SUBA',
#  'barrio_SANTA TERESITA',
#  'barrio_SANTA VIVIANA',
#  'barrio_SANTANDER',
#  'barrio_SANTIAGO PEREZ',
#  'barrio_SANTO DOMINGO',
#  'barrio_SAUCEDAL',
#  'barrio_SEMINARIO',
#  'barrio_SENA',
#  'barrio_SERRANIAS',
#  'barrio_SERRANIAS I',
#  'barrio_SEVILLA',
#  'barrio_SIBERIA',
#  'barrio_SIBERIA  II',
#  'barrio_SIBERIA CENTRAL',
#  'barrio_SIBERIA RURAL',
#  'barrio_SIERRA MORENA',
#  'barrio_SIERRA MORENA II',
#  'barrio_SIETE DE AGOSTO',
#  'barrio_SIMON BOLIVAR',
#  'barrio_SOCIEGO',
#  'barrio_SOSIEGO SUR',
#  'barrio_SOTAVENTO',
#  'barrio_SUBA CERROS',
#  'barrio_SUBA URBANO',
#  'barrio_SUCRE',
#  'barrio_SUMAPAZ',
#  'barrio_SURAMERICA',
#  'barrio_TABORA',
#  'barrio_TAIRONA',
#  'barrio_TECHO',
#  'barrio_TEJAR',
#  'barrio_TERMINAL DE TRANSPORTES',
#  'barrio_TEUSAQUILLO',
#  'barrio_TIBABITA',
#  'barrio_TIBABITA RURAL I',
#  'barrio_TIBABUYES',
#  'barrio_TIBABUYES II',
#  'barrio_TIBABUYES OCCIDENTAL',
#  'barrio_TIBANA',
#  'barrio_TIBAQUE I',
#  'barrio_TIBAQUE II',
#  'barrio_TIBAQUE SUR',
#  'barrio_TIHUAQUE',
#  'barrio_TIMIZA',
#  'barrio_TIMIZA A',
#  'barrio_TINTALA',
#  'barrio_TINTALITO',
#  'barrio_TOCAIMITA ORIENTAL',
#  'barrio_TOCAIMITA ORIENTAL I',
#  'barrio_TOCAIMITA SUR',
#  'barrio_TOCAREMA',
#  'barrio_TORCA I',
#  'barrio_TORCA II',
#  'barrio_TORCA RURAL II',
#  'barrio_TOSCANA',
#  'barrio_TTES DE COLOMBIA',
#  'barrio_TUNA ALTA',
#  'barrio_TUNA BAJA',
#  'barrio_TUNAL ALTO',
#  'barrio_TUNAL ORIENTAL',
#  'barrio_TUNDAMA',
#  'barrio_TUNJUELITO',
#  'barrio_USAQUEN',
#  'barrio_USATAMA',
#  'barrio_USMINIA',
#  'barrio_VALLADOLID',
#  'barrio_VEINTE DE JULIO',
#  'barrio_VELODROMO',
#  'barrio_VENECIA',
#  'barrio_VENECIA OCCIDENTAL',
#  'barrio_VERACRUZ',
#  'barrio_VERAGUAS',
#  'barrio_VERBENAL SAN ANTONIO',
#  'barrio_VEREDA EL TINTAL',
#  'barrio_VEREDA EL TINTAL RURAL',
#  'barrio_VEREDA EL TINTAL URBANO',
#  'barrio_VEREDA SUBA CERROS II',
#  'barrio_VEREDA SUBA NARANJOS',
#  'barrio_VERGEL OCCIDENTAL',
#  'barrio_VERONA',
#  'barrio_VERSALLES FONTIBON',
#  'barrio_VICTORIA NORTE',
#  'barrio_VILLA ALCAZAR',
#  'barrio_VILLA ALSACIA',
#  'barrio_VILLA ALSACIA II',
#  'barrio_VILLA AMALIA',
#  'barrio_VILLA ANITA',
#  'barrio_VILLA ANNY I',
#  'barrio_VILLA ANNY II',
#  'barrio_VILLA CANDELARIA',
#  'barrio_VILLA CARMENZA',
#  'barrio_VILLA DE LOS ALPES',
#  'barrio_VILLA DE LOS ALPES I',
#  'barrio_VILLA DEL CERRO',
#  'barrio_VILLA DEL MAR',
#  'barrio_VILLA DEL PRADO',
#  'barrio_VILLA DEL RIO',
#  'barrio_VILLA DIANA',
#  'barrio_VILLA ELISA',
#  'barrio_VILLA EMMA',
#  'barrio_VILLA GLADYS',
#  'barrio_VILLA GLORIA',
#  'barrio_VILLA HERMOSA',
#  'barrio_VILLA ISRAEL',
#  'barrio_VILLA LUZ',
#  'barrio_VILLA MARIA',
#  'barrio_VILLA MARIA I',
#  'barrio_VILLA MAYOR',
#  'barrio_VILLA NELLY III SECTOR',
#  'barrio_VILLA SAGRARIO',
#  'barrio_VILLABEL',
#  'barrio_VILLAS DE ALCALA',
#  'barrio_VILLAS DE GRANADA',
#  'barrio_VILLAS DE GRANADA I',
#  'barrio_VILLAS DEL PROGRESO',
#  'barrio_VILLAS EL DIAMANTE',
#  'barrio_VILLEMAR',
#  'barrio_VISION DE ORIENTE',
#  'barrio_VITELMA',
#  'barrio_VOTO NACIONAL',
#  'barrio_YOMASA',
#  'barrio_YOMASA NORTE',
#  'barrio_ZONA FRANCA',
#  'edad_(10, 19]',
#  'edad_(20, 29]',
#  'edad_(30, 39]',
#  'edad_(40, 49]',
#  'edad_(50, 59]',
#  'edad_(60, 69]',
#  'edad_(70, 79]',
#  'edad_(80, 89]',
#  'edad_(90, 99]',
#  'sexo_FEMENINO',
#  'sexo_MASCULINO',
#  'sexo_NO REPORTA',
#  'sexo_NO REPORTADA',
#  'hora_0.0',
#  'hora_1.0',
#  'hora_2.0',
#  'hora_3.0',
#  'hora_4.0',
#  'hora_5.0',
#  'hora_6.0',
#  'hora_7.0',
#  'hora_8.0',
#  'hora_9.0',
#  'hora_10.0',
#  'hora_11.0',
#  'hora_12.0',
#  'hora_13.0',
#  'hora_14.0',
#  'hora_15.0',
#  'hora_16.0',
#  'hora_17.0',
#  'hora_18.0',
#  'hora_19.0',
#  ...]
