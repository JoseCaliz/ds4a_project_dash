# %% [markdown]
# # Data Lesiones Homicidios

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime
import os
from unidecode import unidecode

# %%
driver = 'postgres'
username = 'ds4a'
password = 'ds4A-7eaM79'
host = 'ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com'
port = 5432
database = 'team_79'

connection_string = f'{driver}://{username}@{host}:{port}/{database}'
engine = create_engine(connection_string, encoding='utf-8')

# %%
files_1 = ['./data/homicidios/' + str(i) + '.xlsx' for i in range(2010, 2013)]
files_2 = ['./data/homicidios/' + str(i) + '.xls' for i in range(2013, 2020)]
files = files_1+files_2
print(files)
# Out:
# ['./data/homicidios/2010.xlsx', './data/homicidios/2011.xlsx', './data/homicidios/2012.xlsx', './data/homicidios/2013.xls', './data/homicidios/2014.xls', './data/homicidios/2015.xls', './data/homicidios/2016.xls', './data/homicidios/2017.xls', './data/homicidios/2018.xls', './data/homicidios/2019.xls']

# %%
all_dfs = []

for file in files:
    temp = pd.read_excel(file)
    
    # Eliminar acentos en el nombre de las columnas
    temp.columns = [unidecode(str(col)) for col in temp.columns]

    # Reemplazar espacios por _
    temp.columns = temp.columns.str.replace(' ', '_')
    
    # Strip
    temp.columns = temp.columns.str.strip()

    # Reemplazar espacios por _
    temp.columns = temp.columns.str.lower()

    # Reemplazar NaN, None
    temp.replace('-', np.nan, inplace=True)

    # Set axis name
    temp.rename_axis('id', inplace=True)
    
    all_dfs.append(temp)

# %%
renaming={
    'clase_sitio':'clase_de_sitio',
    'pais_nace':'pais_de_nacimiento',
    'clase_empleado':'clase_de_empleado'
}

for i in range(len(all_dfs)):
    all_dfs[i].rename(columns=renaming, inplace=True)
    
df_f = pd.concat(all_dfs, axis=0)

# %%
df_f # also try: .describe
# Out:
#                                                    fecha departamento  \
# id
# 0                                    2010-01-01 00:00:00    ANTIOQUIA
# 1                                    2010-01-01 00:00:00    ANTIOQUIA
# 2                                    2010-01-01 00:00:00    ANTIOQUIA
# 3                                    2010-01-01 00:00:00    ANTIOQUIA
# 4                                    2010-01-01 00:00:00    ANTIOQUIA
# ...                                                  ...          ...
# 12512                                2019-12-31 00:00:00        VALLE
# 12513                                                NaN          NaN
# 12514  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
# 12515                Elaboró: PT. Andrés Felipe Taborda           NaN
# 12516               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#            municipio      dia      hora                     barrio    zona  \
# id
# 0              AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
# 1         COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
# 2      MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
# 3      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...              ...      ...       ...                        ...     ...
# 12512          TULUÁ   Martes  23:50:00              Villa Liliana  URBANA
# 12513            NaN      NaN       NaN                        NaN     NaN
# 12514            NaN      NaN       NaN                        NaN     NaN
# 12515            NaN      NaN       NaN                        NaN     NaN
# 12516            NaN      NaN       NaN                        NaN     NaN
#
#                            clase_de_sitio  arma_empleada movil_agresor  ...  \
# id                                                                      ...
# 0                      FINCAS Y SIMILARES    ARMA BLANCA         A PIE  ...
# 1      FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO         A PIE  ...
# 2                           VIAS PUBLICAS  ARMA DE FUEGO         A PIE  ...
# 3                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE  ...
# 4                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE  ...
# ...                                   ...            ...           ...  ...
# 12512                       VIAS PUBLICAS  ARMA DE FUEGO     BICICLETA  ...
# 12513                                 NaN            NaN           NaN  ...
# 12514                                 NaN            NaN           NaN  ...
# 12515                                 NaN            NaN           NaN  ...
# 12516                                 NaN            NaN           NaN  ...
#
#       pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# id
# 0               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 1               COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 2               COLOMBIA          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 3               COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 4               COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# ...                  ...                  ...           ...         ...
# 12512           COLOMBIA  EMPLEADO PARTICULAR           NaN  SECUNDARIA
# 12513                NaN                  NaN           NaN         NaN
# 12514                NaN                  NaN           NaN         NaN
# 12515                NaN                  NaN           NaN         NaN
# 12516                NaN                  NaN           NaN         NaN
#
#       codigo_dane 2010 2011 2012  profesion  cantidad
# id
# 0       5030000.0  1.0  NaN  NaN        NaN       NaN
# 1       5212000.0  1.0  NaN  NaN        NaN       NaN
# 2       5001000.0  1.0  NaN  NaN        NaN       NaN
# 3       5001000.0  1.0  NaN  NaN        NaN       NaN
# 4       5001000.0  1.0  NaN  NaN        NaN       NaN
# ...           ...  ...  ...  ...        ...       ...
# 12512  76834000.0  NaN  NaN  NaN        NaN       1.0
# 12513         NaN  NaN  NaN  NaN        NaN   12558.0
# 12514         NaN  NaN  NaN  NaN        NaN       NaN
# 12515         NaN  NaN  NaN  NaN        NaN       NaN
# 12516         NaN  NaN  NaN  NaN        NaN       NaN
#
# [136343 rows x 24 columns]

# %%
df_f.isnull().sum()
# Out:
# fecha                      5
# departamento              40
# municipio                 40
# dia                       40
# hora                      40
# barrio                  5119
# zona                      40
# clase_de_sitio            40
# arma_empleada             51
# movil_agresor            712
# movil_victima            522
# edad                      84
# sexo                      40
# estado_civil             688
# pais_de_nacimiento      1678
# clase_de_empleado         40
# profesiones            89689
# escolaridad              868
# codigo_dane               40
# 2010                  121392
# 2011                  120606
# 2012                  120374
# profesion             131991
# cantidad               46687
# dtype: int64

# %%
df_f.drop(columns=['2010','2011','2012','profesion'], inplace=True)

# %%
df_f = df_f.reset_index()

# %%
df_f.drop(columns=['id'], inplace=True)

# %%
df_f = df_f[df_f.isnull().sum(axis=1) < 5]

# %%
df_f
# Out:
#                       fecha departamento      municipio      dia      hora  \
# 0       2010-01-01 00:00:00    ANTIOQUIA          AMAGÁ  Viernes  14:00:00
# 1       2010-01-01 00:00:00    ANTIOQUIA     COPACABANA  Viernes  08:30:00
# 2       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  02:00:00
# 3       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  11:10:00
# 4       2010-01-01 00:00:00    ANTIOQUIA  MEDELLÍN (CT)  Viernes  11:10:00
# ...                     ...          ...            ...      ...       ...
# 136334  2019-12-31 00:00:00        VALLE     CAICEDONIA   Martes  05:05:00
# 136335  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  20:50:00
# 136336  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  00:20:00
# 136337  2019-12-31 00:00:00        VALLE      CALI (CT)   Martes  21:16:00
# 136338  2019-12-31 00:00:00        VALLE          TULUÁ   Martes  23:50:00
#
#                                  barrio    zona  \
# 0                  MALABRIGO PARTE ALTA   RURAL
# 1                       LA MISERICORDIA  URBANA
# 2                      LAS GRANJAS  C-3  URBANA
# 3             ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4             ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...                                 ...     ...
# 136334                  VALLE DEL CAUCA  URBANA
# 136335  VILLA DEL PRADO - EL GUABITO E5  URBANA
# 136336            CIUDADELA FLORALIA E6  URBANA
# 136337         MARIO CORREA RENGIFO E18  URBANA
# 136338                    Villa Liliana  URBANA
#
#                             clase_de_sitio                arma_empleada  \
# 0                       FINCAS Y SIMILARES                  ARMA BLANCA
# 1       FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO
# 2                            VIAS PUBLICAS                ARMA DE FUEGO
# 3                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# 4                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# ...                                    ...                          ...
# 136334                       VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
# 136335                       VIAS PUBLICAS                ARMA DE FUEGO
# 136336                       VIAS PUBLICAS                ARMA DE FUEGO
# 136337              PELUQUERIA Y SIMILARES                ARMA DE FUEGO
# 136338                       VIAS PUBLICAS                ARMA DE FUEGO
#
#                 movil_agresor movil_victima edad       sexo estado_civil  \
# 0                       A PIE         A PIE   49  MASCULINO       CASADO
# 1                       A PIE         A PIE   32  MASCULINO  UNION LIBRE
# 2                       A PIE         A PIE   33  MASCULINO  UNION LIBRE
# 3                       A PIE         A PIE   23  MASCULINO      SOLTERO
# 4                       A PIE         A PIE   23  MASCULINO      SOLTERO
# ...                       ...           ...  ...        ...          ...
# 136334                  A PIE         A PIE   42  MASCULINO      SOLTERO
# 136335                  A PIE         A PIE   36  MASCULINO      SOLTERO
# 136336                  A PIE         A PIE   22  MASCULINO      SOLTERO
# 136337  CONDUCTOR MOTOCICLETA         A PIE   25  MASCULINO      SOLTERO
# 136338              BICICLETA         A PIE   19  MASCULINO  UNION LIBRE
#
#        pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# 0                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 1                COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 2                COLOMBIA          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 3                COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 4                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# ...                   ...                  ...           ...         ...
# 136334           COLOMBIA  EMPLEADO PARTICULAR           NaN    PRIMARIA
# 136335           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136336           COLOMBIA          DESEMPLEADO           NaN    PRIMARIA
# 136337           COLOMBIA        INDEPENDIENTE           NaN    PRIMARIA
# 136338           COLOMBIA  EMPLEADO PARTICULAR           NaN  SECUNDARIA
#
#         codigo_dane  cantidad
# 0         5030000.0       NaN
# 1         5212000.0       NaN
# 2         5001000.0       NaN
# 3         5001000.0       NaN
# 4         5001000.0       NaN
# ...             ...       ...
# 136334   76122000.0       1.0
# 136335   76001000.0       1.0
# 136336   76001000.0       1.0
# 136337   76001000.0       1.0
# 136338   76834000.0       1.0
#
# [136238 rows x 20 columns]

# %%
df_f.hora = pd.to_datetime(df_f.hora, format='%H:%M:%S')
df_f['year'] = df_f.fecha.dt.year
df_f['hora_int'] = df_f.hora.dt.hour

# %%
df_f.edad.replace('NO REPORTADO', np.nan, inplace=True)

# %%
df_f.edad = df_f.edad.astype(float)

# %%
df_f.municipio.replace(' \(CT\)', '', regex=True, inplace=True)
df_f.municipio.replace('BOGOTÁ', 'BOGOTA D.C', inplace=True)
df_f.departamento.replace('BOGOTÁ', 'BOGOTA D.C', inplace=True)
df_f.departamento.replace('GUAJIRA', 'LA GUAJIRA', inplace=True)
df_f.departamento.replace('VALLE', 'VALLE DEL CAUCA', inplace=True)
df_f.departamento.replace('NARIÑO', 'NARINO', inplace=True)

# %%
df_f.fecha = pd.to_datetime(df_f.fecha, format='%Y:%M:%D')

# %%
df_f
# Out:
#             fecha     departamento   municipio      dia                hora  \
# 0      2010-01-01        ANTIOQUIA       AMAGÁ  Viernes 1900-01-01 14:00:00
# 1      2010-01-01        ANTIOQUIA  COPACABANA  Viernes 1900-01-01 08:30:00
# 2      2010-01-01        ANTIOQUIA    MEDELLÍN  Viernes 1900-01-01 02:00:00
# 3      2010-01-01        ANTIOQUIA    MEDELLÍN  Viernes 1900-01-01 11:10:00
# 4      2010-01-01        ANTIOQUIA    MEDELLÍN  Viernes 1900-01-01 11:10:00
# ...           ...              ...         ...      ...                 ...
# 136334 2019-12-31  VALLE DEL CAUCA  CAICEDONIA   Martes 1900-01-01 05:05:00
# 136335 2019-12-31  VALLE DEL CAUCA        CALI   Martes 1900-01-01 20:50:00
# 136336 2019-12-31  VALLE DEL CAUCA        CALI   Martes 1900-01-01 00:20:00
# 136337 2019-12-31  VALLE DEL CAUCA        CALI   Martes 1900-01-01 21:16:00
# 136338 2019-12-31  VALLE DEL CAUCA       TULUÁ   Martes 1900-01-01 23:50:00
#
#                                  barrio    zona  \
# 0                  MALABRIGO PARTE ALTA   RURAL
# 1                       LA MISERICORDIA  URBANA
# 2                      LAS GRANJAS  C-3  URBANA
# 3             ALEJANDRO ECHAVARRIA  C-9  URBANA
# 4             ALEJANDRO ECHAVARRIA  C-9  URBANA
# ...                                 ...     ...
# 136334                  VALLE DEL CAUCA  URBANA
# 136335  VILLA DEL PRADO - EL GUABITO E5  URBANA
# 136336            CIUDADELA FLORALIA E6  URBANA
# 136337         MARIO CORREA RENGIFO E18  URBANA
# 136338                    Villa Liliana  URBANA
#
#                             clase_de_sitio                arma_empleada  \
# 0                       FINCAS Y SIMILARES                  ARMA BLANCA
# 1       FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO
# 2                            VIAS PUBLICAS                ARMA DE FUEGO
# 3                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# 4                    ESCENARIOS DEPORTIVOS                ARMA DE FUEGO
# ...                                    ...                          ...
# 136334                       VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
# 136335                       VIAS PUBLICAS                ARMA DE FUEGO
# 136336                       VIAS PUBLICAS                ARMA DE FUEGO
# 136337              PELUQUERIA Y SIMILARES                ARMA DE FUEGO
# 136338                       VIAS PUBLICAS                ARMA DE FUEGO
#
#                 movil_agresor  ...       sexo  estado_civil  \
# 0                       A PIE  ...  MASCULINO        CASADO
# 1                       A PIE  ...  MASCULINO   UNION LIBRE
# 2                       A PIE  ...  MASCULINO   UNION LIBRE
# 3                       A PIE  ...  MASCULINO       SOLTERO
# 4                       A PIE  ...  MASCULINO       SOLTERO
# ...                       ...  ...        ...           ...
# 136334                  A PIE  ...  MASCULINO       SOLTERO
# 136335                  A PIE  ...  MASCULINO       SOLTERO
# 136336                  A PIE  ...  MASCULINO       SOLTERO
# 136337  CONDUCTOR MOTOCICLETA  ...  MASCULINO       SOLTERO
# 136338              BICICLETA  ...  MASCULINO   UNION LIBRE
#
#        pais_de_nacimiento    clase_de_empleado   profesiones escolaridad  \
# 0                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 1                COLOMBIA        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 2                COLOMBIA          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 3                COLOMBIA           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 4                COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# ...                   ...                  ...           ...         ...
# 136334           COLOMBIA  EMPLEADO PARTICULAR           NaN    PRIMARIA
# 136335           COLOMBIA        INDEPENDIENTE           NaN  SECUNDARIA
# 136336           COLOMBIA          DESEMPLEADO           NaN    PRIMARIA
# 136337           COLOMBIA        INDEPENDIENTE           NaN    PRIMARIA
# 136338           COLOMBIA  EMPLEADO PARTICULAR           NaN  SECUNDARIA
#
#        codigo_dane cantidad  year  hora_int
# 0        5030000.0      NaN  2010        14
# 1        5212000.0      NaN  2010         8
# 2        5001000.0      NaN  2010         2
# 3        5001000.0      NaN  2010        11
# 4        5001000.0      NaN  2010        11
# ...            ...      ...   ...       ...
# 136334  76122000.0      1.0  2019         5
# 136335  76001000.0      1.0  2019        20
# 136336  76001000.0      1.0  2019         0
# 136337  76001000.0      1.0  2019        21
# 136338  76834000.0      1.0  2019        23
#
# [136238 rows x 22 columns]

# %%
df_f['FECHA'] = pd.to_datetime(df_f.fecha.astype(str)+' '+df_f.hora.astype(str))

# %%
df_f.drop(columns=['fecha'], inplace = True)
#df_f.rename(columns={'fecha':'FECHA'}, inplace=True)

# %%
df_f.rename(columns={'FECHA':'fecha'}, inplace=True)

# %%
df_f.drop(columns=['hora'], inplace = True)
df_f.rename(columns={'hora_int':'hora'}, inplace=True)

# %%
df_f['cantidad'].describe()
# Out:
# count    89584.000000
# mean         1.002255
# std          0.069084
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         14.000000
# Name: cantidad, dtype: float64

# %%
df_f.cantidad.fillna(1, inplace=True)
df_f = pd.DataFrame(
    df_f.values.repeat(df_f.cantidad.astype(int), axis=0),
    columns=df_f.columns
)
df_f.drop(columns=['cantidad'], inplace=True)

# %%
#df_f.drop(columns=['hora'], inplace=True)

# %%
df_f
# Out:
#            departamento   municipio      dia                           barrio  \
# 0             ANTIOQUIA       AMAGÁ  Viernes             MALABRIGO PARTE ALTA
# 1             ANTIOQUIA  COPACABANA  Viernes                  LA MISERICORDIA
# 2             ANTIOQUIA    MEDELLÍN  Viernes                 LAS GRANJAS  C-3
# 3             ANTIOQUIA    MEDELLÍN  Viernes        ALEJANDRO ECHAVARRIA  C-9
# 4             ANTIOQUIA    MEDELLÍN  Viernes        ALEJANDRO ECHAVARRIA  C-9
# ...                 ...         ...      ...                              ...
# 136435  VALLE DEL CAUCA  CAICEDONIA   Martes                  VALLE DEL CAUCA
# 136436  VALLE DEL CAUCA        CALI   Martes  VILLA DEL PRADO - EL GUABITO E5
# 136437  VALLE DEL CAUCA        CALI   Martes            CIUDADELA FLORALIA E6
# 136438  VALLE DEL CAUCA        CALI   Martes         MARIO CORREA RENGIFO E18
# 136439  VALLE DEL CAUCA       TULUÁ   Martes                    Villa Liliana
#
#           zona                      clase_de_sitio  \
# 0        RURAL                  FINCAS Y SIMILARES
# 1       URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 2       URBANA                       VIAS PUBLICAS
# 3       URBANA               ESCENARIOS DEPORTIVOS
# 4       URBANA               ESCENARIOS DEPORTIVOS
# ...        ...                                 ...
# 136435  URBANA                       VIAS PUBLICAS
# 136436  URBANA                       VIAS PUBLICAS
# 136437  URBANA                       VIAS PUBLICAS
# 136438  URBANA              PELUQUERIA Y SIMILARES
# 136439  URBANA                       VIAS PUBLICAS
#
#                       arma_empleada          movil_agresor movil_victima edad  \
# 0                       ARMA BLANCA                  A PIE         A PIE   49
# 1                     ARMA DE FUEGO                  A PIE         A PIE   32
# 2                     ARMA DE FUEGO                  A PIE         A PIE   33
# 3                     ARMA DE FUEGO                  A PIE         A PIE   23
# 4                     ARMA DE FUEGO                  A PIE         A PIE   23
# ...                             ...                    ...           ...  ...
# 136435  ARMA BLANCA / CORTOPUNZANTE                  A PIE         A PIE   42
# 136436                ARMA DE FUEGO                  A PIE         A PIE   36
# 136437                ARMA DE FUEGO                  A PIE         A PIE   22
# 136438                ARMA DE FUEGO  CONDUCTOR MOTOCICLETA         A PIE   25
# 136439                ARMA DE FUEGO              BICICLETA         A PIE   19
#
#              sexo estado_civil pais_de_nacimiento    clase_de_empleado  \
# 0       MASCULINO       CASADO           COLOMBIA  EMPLEADO PARTICULAR
# 1       MASCULINO  UNION LIBRE           COLOMBIA        INDEPENDIENTE
# 2       MASCULINO  UNION LIBRE           COLOMBIA          DESEMPLEADO
# 3       MASCULINO      SOLTERO           COLOMBIA           ESTUDIANTE
# 4       MASCULINO      SOLTERO           COLOMBIA  EMPLEADO PARTICULAR
# ...           ...          ...                ...                  ...
# 136435  MASCULINO      SOLTERO           COLOMBIA  EMPLEADO PARTICULAR
# 136436  MASCULINO      SOLTERO           COLOMBIA        INDEPENDIENTE
# 136437  MASCULINO      SOLTERO           COLOMBIA          DESEMPLEADO
# 136438  MASCULINO      SOLTERO           COLOMBIA        INDEPENDIENTE
# 136439  MASCULINO  UNION LIBRE           COLOMBIA  EMPLEADO PARTICULAR
#
#          profesiones escolaridad codigo_dane  year hora  \
# 0       NO REPORTADO    PRIMARIA    5.03e+06  2010   14
# 1       NO REPORTADO  SECUNDARIA   5.212e+06  2010    8
# 2       NO REPORTADO  SECUNDARIA   5.001e+06  2010    2
# 3       NO REPORTADO  SECUNDARIA   5.001e+06  2010   11
# 4       NO REPORTADO  SECUNDARIA   5.001e+06  2010   11
# ...              ...         ...         ...   ...  ...
# 136435           NaN    PRIMARIA  7.6122e+07  2019    5
# 136436           NaN  SECUNDARIA  7.6001e+07  2019   20
# 136437           NaN    PRIMARIA  7.6001e+07  2019    0
# 136438           NaN    PRIMARIA  7.6001e+07  2019   21
# 136439           NaN  SECUNDARIA  7.6834e+07  2019   23
#
#                            fecha
# 0      2010-01-01 14:00:00-01:00
# 1      2010-01-01 08:30:00-01:00
# 2      2010-01-01 02:00:00-01:00
# 3      2010-01-01 11:10:00-01:00
# 4      2010-01-01 11:10:00-01:00
# ...                          ...
# 136435 2019-12-31 05:05:00-01:00
# 136436 2019-12-31 20:50:00-01:00
# 136437 2019-12-31 00:20:00-01:00
# 136438 2019-12-31 21:16:00-01:00
# 136439 2019-12-31 23:50:00-01:00
#
# [136440 rows x 20 columns]

# %%
df_f.to_csv('/home/santiagotc/Documents/DS4A-MinTic/Project/lesiones_personales/homicidios_3.csv', index=False)

# %%
driver = 'postgres'
username = 'ds4a'
password = 'ds4A-7eaM79'
host = 'ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com'
port = 5432
database = 'team_79'

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://ds4a:ds4A-7eaM79@ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com/team_79
# Out:
# 'Connected: ds4a@team_79'

# %%
df_f = pd.read_csv('/home/santiagotc/Documents/DS4A-MinTic/Project/lesiones_personales/homicidios_2.csv')

# %%
df_f.columns

# %%
df_f.rename(columns={'FECHA':'fecha', 'HORA':'hora'}, inplace = True)

# %%
df_f.drop(columns = 'year', inplace = True)

# %%
df_f.drop(columns = 'cantidad', inplace = True)

# %%
df_f

# %%
df_f.columns
# Out:
# Index(['departamento', 'municipio', 'dia', 'barrio', 'zona', 'clase_de_sitio',
#        'arma_empleada', 'movil_agresor', 'movil_victima', 'edad', 'sexo',
#        'estado_civil', 'pais_de_nacimiento', 'clase_de_empleado',
#        'profesiones', 'escolaridad', 'codigo_dane', 'year', 'hora', 'fecha'],
#       dtype='object')

# %%
# %%sql
# DROP TABLE homicidios2
# Out:
#  * postgresql://ds4a:***@ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com/team_79
# Done.
# []

# %%
# %%sql
# CREATE TABLE homicidios2 (
#  departamento TEXT,
#  municipio TEXT,
#  dia TEXT,
#  barrio TEXT,
#  zona TEXT,
#  clase_de_sitio TEXT,
#  arma_empleada TEXT,
#  movil_agresor TEXT,
#  movil_victima TEXT,
#  edad FLOAT,
#  sexo TEXT,
#  estado_civil TEXT,
#  pais_de_nacimiento TEXT,
#  clase_de_empleado TEXT,
#  profesiones TEXT,
#  escolaridad TEXT,
#  codigo_dane FLOAT,
#  year FLOAT,
#  hora FLOAT,
#  fecha TIMESTAMP
#  );
# Out:
#  * postgresql://ds4a:***@ds4a.cm1dcdf7pnnv.us-east-2.rds.amazonaws.com/team_79
# Done.
# []

# %% [markdown]
# ```sql
# \copy homicidios FROM '/home/santiagotc/Documents/DS4A-MinTic/Project/lesiones_personales/homicidios_2.csv' with (format CSV, header true, delimiter ',');
# ```

# %% [markdown]
# # EDA

# %%
# !pwd

# %%
df_f

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 14
# mpl.rcParams.keys()
sns.set_palette('Accent')

# %%
plt.figure(figsize=(16,9))
ax = sns.lineplot(
                    data=df_f.groupby('fecha').apply(lambda df: df.sexo.value_counts()).reset_index(),
                    x='fecha',
                    y='sexo',
                    hue='level_1'
                 )
 
ax.set_title('Time Series Total Cases Per Day');
ax.legend(['Male', 'Female', 'Not Found']);

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,9))
ax = sns.countplot(# count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.
                   data = df_f,
                   x='year',
                   hue='sexo'
                  )

ax.set_title('Counts per Year');
ax.legend(['Mascullino', 'Femenino']);

plt.savefig('figura1.png')

# %%
plt.figure(figsize=(16,9))
ax = sns.countplot(
                    data=df_f,
                    x='departamento'
)

plt.xticks(rotation=45,ha='right');

# %%
plt.figure(figsize=(16,9))

order = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
ax = sns.countplot(
                   data=df_f,
                   x='dia',
                   order=order
                  )

# %%
plt.figure(figsize=(16,9))
ax = sns.countplot(
    data=df_f,
    x='zona',
)

# %%
plt.figure(figsize=(16,9))

sns.barplot(
    data=df_f.clase_de_sitio.value_counts().head(10).to_frame(name='count').reset_index(),
    x='index',
    y='count'
) 

plt.xticks(rotation=45, ha='right');

# %%
plt.figure(figsize=(16,9))

sns.countplot(
    data=df_f,
    x='escolaridad',
);

# %%
plt.figure(figsize=(16,9))

sns.countplot(
    data=df_f,
    x='arma_empleada',
);
plt.xticks(rotation=45, ha='right');

# %%
plt.figure(figsize=(16,9))

sns.barplot(
    data=df_f.profesiones.value_counts().to_frame('count').reset_index().head(10),
    x='index',
    y='count'
) 

plt.xticks(rotation=45, ha='right');

# %%
plt.figure(figsize=(16,9))
sns.countplot(
    df_f.hora_int
);

plt.savefig('figura_2.png')

# %%
plt.figure(figsize=(16,9))

sns.distplot(
    df_f.edad
);

# %%
sns.set_palette('Set1')
fig, ax = plt.subplots(figsize=(16,9))
sns.violinplot(
    data=df_f[df_f.sexo != "NO REPORTA"],
    x='year',
    y='hora_int',
    hue='sexo',
    ax=ax,
    split=True,
    palette="Accent"
);

# %%
fig, ax = plt.subplots(5, 1, figsize=(16,20), sharex=True)
i=0
for year in np.arange(2015,2020):
    sns.distplot(
        df_f.loc[((df_f.sexo == 'MASCULINO') & (df_f.year == year)), 'hora_int'],
        bins=20,
        color='limegreen',
        label='Male',
        ax=ax[i]
    )

    sns.distplot(
        df_f.loc[((df_f.sexo == 'FEMENINO') & (df_f.year == year)), 'hora_int'],
        bins=20,
        color='orchid',
        label='Female',
        ax=ax[i]
    )
    ax[i].set_title(str(year))
    ax[i].set_xlabel('')
    i+=1

ax[0].legend()
ax[-1].set_xlabel('Hora Del Incidente');

# %% [markdown]
# ## Maps of counts

# %%
import json

with open('./data/geojson_departamentos.json', 'r') as f:
    departamentos = json.load(f)
    
areas = pd.read_json('./data/areas_departamentos.json',
                     orient='index')
# with open('./data/geoJson_departamentos.json', 'w') as f:
#     json.dump(departamentos, f)

# with open('./data/areas_departamentos.json', 'w') as f:
#     json.dump(areas, f)

# %%
import plotly.express as px

# %%
df_f.departamento = df_f.departamento.apply(unidecode)

# %%
count_2019 = df_f[df_f.year == 2019].departamento.value_counts().reset_index(name='count')
fig = px.choropleth_mapbox(
    count_2019,
    geojson=departamentos,
    locations='index',
    color='count',
    color_continuous_scale="Viridis",
    mapbox_style="carto-positron",
    zoom=4,
    center = {"lat": 3.47, "lon": -73.96},
    opacity=0.5
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
